# %%
#AES 256 BIT ENCYRPTION & DECRYPTION sbox for encryption & inverse s-box for decryption
sbox = [
        
]
sbox_inv= [
        
]

# %%
def convert_key_to_256bit(key):
    if len(key) != 32:
        raise ValueError("Key must be exactly 32 ASCII characters (256 bits).")
    # Convert the ASCII key to bytes and then to a hex string
    hex_key = key.encode('utf-8').hex()
    return hex_key.upper()  # Uppercase for readability

# %%
def convert_input_to_128bit(input):
    n=len(input)
    if n != 16:
        input += '\x06'*((1+n//16)*16 - n)
    # Convert the ASCII input to bytes and then to a hex string
    hex_input = input.encode('utf-8').hex()
    return hex_input.upper()

# %%
def g_function(word, round_constant, sbox):
    rotated_word = word[1:] + word[:1]  
    # subWord - Apply S-Box Substitution
    subbed_word = [sbox[int(byte, 16)] for byte in rotated_word]  # Convert to int for lookup
    #  XOR First Byte with Round Constant (Rcon[i])
    subbed_word[0] ^= round_constant
    # Convert to hexadecimal format
    return [format(byte, '02X') for byte in subbed_word]

def generate_all_keys(key, sbox, rcon):
    """
    Generates all 15 round keys for AES-256 (Key Expansion Algorithm)
    :param key: 32-character ASCII key
    :param sbox: AES S-Box table
    :param rcon: List of round constants
    :return: List of all 15 round keys (each 4x4 matrix)
    """
    # Convert key to 256-bit hex
    str_key = key.encode('utf-8').hex()
    words = [[str_key[i:i+2] for i in range(j, j+8, 2)] for j in range(0, 64, 8)]  # 8 words (32 bytes)
    # Generate w[8] to w[59]
    for i in range(8, 60):
        if i % 8 == 0:
            g_word = g_function(words[i-1], rcon[i//8 - 1], sbox)
            new_word = [format(int(words[i-8][j], 16) ^ int(g_word[j], 16), '02X') for j in range(4)]
        elif i % 8 == 4:
            subbed_word = [sbox[int(byte, 16)] for byte in words[i-1]]
            new_word = [format(int(words[i-8][j], 16) ^ subbed_word[j], '02X') for j in range(4)]
        else:
            new_word = [format(int(words[i-8][j], 16) ^ int(words[i-1][j], 16), '02X') for j in range(4)]
        words.append(new_word)
    
    # Group words into 15 round keys (each 4x4 matrix)
    round_keys = [words[i:i+4] for i in range(0, 60, 4)]
    return round_keys

# %%
rcon =  [0x1, 0x2, 0x4, 0x8, 0x10, 0x20, 0x40]
key="1234567890ABC4561234567812345678"
round_keys = generate_all_keys(key, sbox, rcon)
for i, rk in enumerate(round_keys):
    print(f"Round {i} Key:")
    for row in rk:
        print(" ".join(row))
    print()
# Out:
# Round 0 Key:
# 31 32 33 34
# 35 36 37 38
# 39 30 41 42
# 43 34 35 36
#
# Round 1 Key:
# 31 32 33 34
# 35 36 37 38
# 31 32 33 34
# 35 36 37 38
#
# Round 2 Key:
# 35 A8 34 A2
# 00 9E 03 9A
# 39 AE 42 D8
# 7A 9A 77 EE
#
# Round 3 Key:
# EB 8A C6 1C
# DE BC F1 24
# EF 8E C2 10
# DA B8 F5 28
#
# Round 4 Key:
# 5B 4E 00 F5
# 5B D0 03 6F
# 62 7E 41 B7
# 18 E4 36 59
#
# Round 5 Key:
# 46 E3 C3 D7
# 98 5F 32 F3
# 77 D1 F0 E3
# AD 69 05 CB
#
# Round 6 Key:
# A6 25 1F 60
# FD F5 1C 0F
# 9F 8B 5D B8
# 87 6F 6B E1
#
# Round 7 Key:
# 51 4B BC 2F
# C9 14 8E DC
# BE C5 7E 3F
# 13 AC 7B F4
#
# Round 8 Key:
# 3F 04 A0 1D
# C2 F1 BC 12
# 5D 7A E1 AA
# DA 15 8A 4B
#
# Round 9 Key:
# 06 12 C2 9C
# CF 06 4C 40
# 71 C3 32 7F
# 62 6F 49 8B
#
# Round 10 Key:
# 87 3F 9D B7
# 45 CE 21 A5
# 18 B4 C0 0F
# C2 A1 4A 44
#
# Round 11 Key:
# 23 20 14 87
# EC 26 58 C7
# 9D E5 6A B8
# FF 8A 23 33
#
# Round 12 Key:
# D9 19 5E A1
# 9C D7 7F 04
# 84 63 BF 0B
# 46 C2 F5 4F
#
# Round 13 Key:
# 79 05 F2 03
# 95 23 AA C4
# ...

# %%
def transform_matrix(matrix):
    n = len(matrix)  # Get the size of the matrix
    return [[matrix[row][col] for row in range(n)] for col in range(n)]
def xor_hex_matrices(matrix1, matrix2):
    n = len(matrix1)  # Get matrix size
    # Compute XOR elementwise and format as uppercase hex strings
    result = [[format(int(matrix1[row][col], 16) ^ int(matrix2[row][col], 16), '02X')
               for col in range(n)] for row in range(n)]
    return result
def round_zero(input,key_R0):
    str_input= convert_input_to_128bit(input);
    input_mat= [[str_input[i:i+2] for i in range(j, j+8, 2)] for j in range(0, 32, 8)]
    transformed_input_mat=transform_matrix(input_mat);
    transformed_R0_key=transform_matrix(key_R0);
    state_matrix=xor_hex_matrices(transformed_input_mat,transformed_R0_key);
    return state_matrix

# %%
def apply_sub_bytes(input_mat):
    return [[format(sbox[int(byte, 16)], '02X') for byte in row] for row in input_mat]
def shift_rows(input_mat):
    return [
        input_mat[0],  # Row 0 remains unchanged
        input_mat[1][1:] + input_mat[1][:1],  # Shift left by 1
        input_mat[2][2:] + input_mat[2][:2],  # Shift left by 2
        input_mat[3][3:] + input_mat[3][:3]   # Shift left by 3
    ]   
def galois_mult(a, b):
    result = 0
    for _ in range(8):
        if b & 1:
            result ^= a
        high_bit_set = a & 0x80
        a = (a << 1) & 0xFF
        if high_bit_set:
            a ^= 0x1B  # AES irreducible polynomial x^8 + x^4 + x^3 + x + 1
        b >>= 1
    return result
multiplying_matrix = [
    ['02', '03', '01', '01'],
    ['01', '02', '03', '01'],
    ['01', '01', '02', '03'],
    ['03', '01', '01', '02']
]
def mix_columns(input_mat, multiplying_mat):
    n = 4 
    output_mat = [[0] * n for _ in range(n)]
    
    for col in range(n):
        for row in range(n):
            output_mat[row][col] = 0
            for k in range(n):
                output_mat[row][col] ^= galois_mult(int(multiplying_mat[row][k], 16), int(input_mat[k][col], 16))
            output_mat[row][col] = format(output_mat[row][col], '02X')
    
    return output_mat
def add_round_key(mat1,mat2):
    return xor_hex_matrices(mat1,mat2);

# %%
def Ith_Round(mat,i):
     output_sub_bytes_i=apply_sub_bytes(mat);
     output_shift_rows_i=shift_rows(output_sub_bytes_i);
     output_mix_columns_i=mix_columns(output_shift_rows_i,multiplying_matrix);   
     output_add_round_key_i=add_round_key(output_mix_columns_i,transform_matrix(round_keys[i+1]));
     return output_add_round_key_i

# %%
def round_one_to_fourteen(state_matrix):
    for i in range(13):
       if(i==0): 
        cip=Ith_Round(state_matrix,i)
       else:
        cip=Ith_Round(cip,i);  
    #round 14
    output_sub_bytes_14=apply_sub_bytes(cip);
    output_shift_rows_14=shift_rows(output_sub_bytes_14);
    cipher_text=add_round_key(output_shift_rows_14,transform_matrix(round_keys[14]));
    cipher=""
    cip_mat= transform_matrix(cipher_text) 
    for i in  range(len(cip_mat)):
        for j in range(len(cip_mat)):
            cipher+=cip_mat[i][j]+" ";
    return cipher

# %%
#PUTTING ALL IN ONE PLACE
def AES_Encrypt(input,key):
    if(len(input)==0):
        return
    round_keys=generate_all_keys(key, sbox, rcon)
    str_key=convert_key_to_256bit(key)
    state_matrix=round_zero(input,round_keys[0])  
    return round_one_to_fourteen(state_matrix);

# %%
def string_to_utf8_hex(text):
    utf8_bytes = text.encode('utf-8')  # Convert string to UTF-8 bytes
    hex_output = utf8_bytes.hex()      # Convert bytes to hex
    return hex_output

# %%
def generalized_encrypt_AES(input,key):
    if(len(key)!=32):
        raise ValueError("Key must be exactly 32 ASCII characters (256 bits).")
    input=string_to_utf8_hex(input);
    n=len(input)
    cipher_text="";
    n1=0
    extra_padding=0;
    if(n%16!=0):
        extra_padding= (1+n//16)*16-n      
    for i in range(1+n//16):
         if(len(input[i*16:(i+1)*16])==0):
             break;
         cipher_text+=AES_Encrypt(input[i*16:(i+1)*16],key).replace(" ","")
    return cipher_text

# %%
# generalized_encrypt_AES("🥶🥶🥶🩵😇👍🏻😍😃🥳🥳🥳🥳🥶🥰🩵😃😇😘😂🤣😘",key)

# %%
def inv_shift_rows(input_mat):
    return [
        input_mat[0],  # Row 0 remains unchanged
        input_mat[1][-1:] + input_mat[1][:-1],  # Shift right by 1
        input_mat[2][-2:] + input_mat[2][:-2],  # Shift right by 2
        input_mat[3][-3:] + input_mat[3][:-3]   # Shift right by 3
    ]

def inv_sub_bytes(input_mat):
    return [[format(sbox_inv[int(byte, 16)], '02X') for byte in row] for row in input_mat]

inv_multiplying_matrix = [
    ['0E', '0B', '0D', '09'],
    ['09', '0E', '0B', '0D'],
    ['0D', '09', '0E', '0B'],
    ['0B', '0D', '09', '0E']
]

def inv_mix_columns(input_mat, inv_multiplying_mat):
    n = 4  # AES block size
    output_mat = [[0] * n for _ in range(n)]
    
    for col in range(n):
        for row in range(n):
            output_mat[row][col] = 0
            for k in range(n):
                output_mat[row][col] ^= galois_mult(int(inv_multiplying_mat[row][k], 16), int(input_mat[k][col], 16))
            output_mat[row][col] = format(output_mat[row][col], '02X')
    
    return output_mat

def inv_round_zero(cipher_text, key_R12):
    cipher_mat = [[cipher_text[i:i+2] for i in range(j, j+8, 2)] for j in range(0, 32, 8)]
    transformed_cipher_mat = transform_matrix(cipher_mat)
    transformed_R12_key = transform_matrix(key_R12)
    state_matrix = xor_hex_matrices(transformed_cipher_mat, transformed_R12_key)
    return state_matrix

def inv_Ith_Round(mat, i):
    output_inv_shift_rows_i = inv_shift_rows(mat)
    output_inv_sub_bytes_i = inv_sub_bytes(output_inv_shift_rows_i)
    output_add_round_key_i = add_round_key(output_inv_sub_bytes_i, transform_matrix(round_keys[13 - i]))
    output_inv_mix_columns_i = inv_mix_columns(output_add_round_key_i, inv_multiplying_matrix)
    return output_inv_mix_columns_i

def inv_round_one_to_fourteen(state_matrix):
    for i in range(13):
        if i == 0:
            cip = inv_Ith_Round(state_matrix, i)
        else:
            cip = inv_Ith_Round(cip, i)
    
    # Round 14
    output_inv_shift_rows_14 = inv_shift_rows(cip)
    output_inv_sub_bytes_14 = inv_sub_bytes(output_inv_shift_rows_14)
    plain_text = add_round_key(output_inv_sub_bytes_14, transform_matrix(round_keys[0]))
    plain = ""
    plain_mat = transform_matrix(plain_text)
    for i in range(len(plain_mat)):
        for j in range(len(plain_mat)):
            plain += plain_mat[i][j] + " "
    return plain

# %%
def AES_Decrypt(cipher_text, key):
    cipher_text_clean = cipher_text.replace(" ", "")
    round_keys = generate_all_keys(key, sbox, rcon)
    state_matrix = inv_round_zero(cipher_text_clean, round_keys[14])
    decrypted_hex = inv_round_one_to_fourteen(state_matrix)
    return decrypted_hex

# %%
def hex_to_plaintext(hex_string):
    try:
        # Convert hex string to bytes
        byte_data = bytes.fromhex(hex_string)
        # Decode bytes to plaintext using ASCII encoding
        plaintext = byte_data.decode('ascii')
        return plaintext
    except ValueError as e:
        # Handle invalid hex strings or decoding errors
        return f"Error: {e}"

# %%
def hex_to_string(hex_input):
    utf8_bytes = bytes.fromhex(hex_input)  
    text = utf8_bytes.decode('utf-8')     
    return text

# %%
def generalized_decrypt_AES(cipher,key):
  n=len(cipher);
  plain_text=""
  for i in range(n//32):
     plain_text+=hex_to_plaintext(AES_Decrypt(cipher[i*32:(i+1)*32],key).replace(" ",""))       
  return hex_to_string(plain_text.rstrip('\x06'))

# %%
user_input= input("enter plain text: ")
cipher_text= generalized_encrypt_AES(user_input,key)
print()
print('cipher text ',cipher_text);
print()
decrypt_text=generalized_decrypt_AES(cipher_text,key)
print("decrypted text : ",decrypt_text)
print(user_input == decrypt_text)
# Out:
# enter plain text:  sjjj sjcsc
# cipher text  8B4874B8F5169FEFF4E7D558B1186565916B264E4867CEAFA39E7C93DEA72ADB
#
# decrypted text :  sjjj sjcsc
# True

# %%
import os
import binascii  # Used for byte-to-hex conversion
key="1234n67d90ABC45612t4j6q812345e78"
# print(len(key))
# Read file as binary and encrypt
def encrypt_file(file_path):
    """Encrypts any file using the given AES encryption function."""
    with open(file_path, "rb") as f:
        file_data = f.read()  # Read file as binary
    
    # Convert bytes to a hexadecimal string representation
    file_data_hex = binascii.hexlify(file_data).decode('utf-8')

    # Encrypt the hex string
    # encrypted_data =  generalized_encrypt_AES(file_data_hex, key)

    encrypted_file_path = file_path +"test"+ ".enc"  # Save as .enc file
    with open(encrypted_file_path, "w") as f:  # Save as text file (since encryption outputs a string)
        f.write(file_data_hex)

    print(f"Encrypted file saved as: {encrypted_file_path}")
    return encrypted_file_path

def decrypt_file(encrypted_file_path, output_file_path):
    """Decrypts an encrypted file and restores the original content."""
    with open(encrypted_file_path, "r") as f:
        encrypted_data = f.read()  # Read encrypted text data
   
    decrypted_data = binascii.unhexlify(decrypted_hex)
    # Decrypt the string back to hex
    # decrypted_hex =  generalized_decrypt_AES(encrypted_data, key)

    # Convert hex back to binary

    # Save the binary data back to a file
    with open(output_file_path, "wb") as f:
        f.write(encrypted_data)

    print(f"Decrypted file saved as: {output_file_path}")

# encrypt_function and decrypt_function should be your AES encrypt/decrypt functions
# encrypt_file("2nd_semester.pdf")
decrypt_file("2nd_semester.pdftest.enc", "decrypted_example_1.pdf")
