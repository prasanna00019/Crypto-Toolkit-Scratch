# %% [markdown]
# # 🧑‍💻 SHA-3 (Keccak) Bit-Level Implementation in Python
#
# Welcome to this educational project where SHA-3 (Keccak) and its variants are implemented **entirely from scratch at the bit level** in Python! 🚀
#
# ## 📚 About
#
# - This notebook provides a **bitwise, step-by-step implementation** of the SHA-3 family, including:
#     - SHA3-224
#     - SHA3-256
#     - SHA3-384
#     - SHA3-512
#     - SHAKE128
#     - SHAKE256
#     - Keccak-224/256/384/512
#
# - **Every function** closely follows the pseudocode and specifications from the official NIST FIPS 202 paper:
#     [SHA-3 Standard: Permutation-Based Hash and Extendable-Output Functions](https://nvlpubs.nist.gov/nistpubs/FIPS/NIST.FIPS.202.pdf) 📄
#
# - The implementation is **bit-level** (not byte-level or word-level), making each transformation (Theta, Rho, Pi, Chi, Iota, etc.) transparent and easy to follow for learning and research purposes.
#
# ## 🛠️ Features
#
# - **From Scratch:** No external cryptographic libraries are used for the core logic—everything is built from the ground up!
# - **Educational:** Each step of the Keccak permutation and sponge construction is implemented and documented for clarity.
# - **Variants Supported:** SHA3, Keccak, and SHAKE (XOF) functions are all included.
# - **Validation:** The outputs are compared with Python's `hashlib` to ensure correctness. ✅
#
# ## 📖 References
#
# - Main reference:
#     [NIST FIPS 202: SHA-3 Standard](https://nvlpubs.nist.gov/nistpubs/FIPS/NIST.FIPS.202.pdf)
#
# - For more details, see the code cells below, where each transformation and function is implemented and explained.
#
# ## 💡 Why Bit-Level?
#
# Implementing SHA-3 at the bit level provides a **deep understanding** of how each transformation works internally. This project was a fascinating journey into the mechanics of modern cryptographic hash functions! 🧩
#
# ## 🧩 Extensions
#
# - The project is extended to support **SHAKE128** and **SHAKE256** (extendable-output functions), as well as all standard SHA-3 hash sizes.
#
# ---
#
# Enjoy exploring and learning from this bitwise SHA-3 implementation!
# Feel free to experiment with the code and see how each step transforms the state. 🧑‍🔬✨

# %%
def reverse_bits_in_byte(b):
    return int('{:08b}'.format(b)[::-1], 2)

def str_to_keccak_bits(msg):
    return ''.join(format(reverse_bits_in_byte(b), '08b') for b in msg.encode('utf-8'))

# %%
def keccak_pad(msg_bits, r, suffix_bits):
    m = list(msg_bits)
    m += list(suffix_bits)
    pad_len = (-len(m) - 1) % r
    m += ['0'] * pad_len
    m.append('1')
    return ''.join(m)

# %%
def string_to_state_array(S, x=5, y=5, w=64):
    """
    Converts a string S of b = x * y * w bits to a 3D state array A[x][y][w].
    Each A[x][y][z] is a bit (0 or 1).
    """
    if len(S) != x * y * w:
        raise ValueError("Length of input S must be x * y * w bits")

    A = [[[0 for z in range(w)] for y_ in range(y)] for x_ in range(x)]

    for i in range(x):
        for j in range(y):
            for k in range(w):
                A[i][j][k] = int(S[w * (5 * j + i) + k])

    return A

def state_array_to_string(A, x=5, y=5, w=64):
    """
    Converts a 3D state array A into a string S as per Keccak specification.
    """
    Lane_i_j = [['' for _ in range(y)] for _ in range(x)]  # 5x5 matrix of empty strings

    for i in range(x):
        for j in range(y):
            for k in range(w):
                # integer bit to string before concatenation
                Lane_i_j[i][j] += str(A[i][j][k])

    plane_j = ['' for _ in range(y)]  # one string for each plane j

    for j in range(y):
        for i in range(x):
            plane_j[j] += Lane_i_j[i][j]

    S = ''.join(plane_j)  # concatenate Plane(0) || Plane(1) || ...
    return S

# %%
def theta(A, w=64):
    """
    Keccak Theta step: modifies the state array A in-place based on the Theta transformation.

    Args:
        A: 3D state array A[x][y][z] where x, y in [0..4], z in [0..w-1]
        w: lane size (e.g., 64 for SHA3-512)

    Returns:
        A′: New state array after applying theta step.
    """
    #Compute C[x][z]
    C = [[0] * w for _ in range(5)]
    for x in range(5):
        for z in range(w):
            C[x][z] = A[x][0][z]
            for y in range(1, 5):
                C[x][z] ^= A[x][y][z]

    # Compute D[x][z]
    D = [[0] * w for _ in range(5)]
    for x in range(5):
        for z in range(w):
            D[x][z] = C[(x - 1) % 5][z] ^ C[(x + 1) % 5][(z - 1) % w]

    A_prime = [[[0] * w for _ in range(5)] for _ in range(5)]
    for x in range(5):
        for y in range(5):
            for z in range(w):
                A_prime[x][y][z] = A[x][y][z] ^ D[x][z]

    return A_prime

# %%
def rho(A, w=64):
    """
    Keccak Rho step: performs bitwise rotations on the lanes of A according to fixed offsets.

    Args:
        A: 3D state array A[x][y][z], where x, y in [0..4], z in [0..w-1]
        w: lane size (e.g., 64 for SHA3-512)

    Returns:
        A_prime: new state array after applying rho step.
    """
    A_prime = [[[0] * w for _ in range(5)] for _ in range(5)]

    for z in range(w):
        A_prime[0][0][z] = A[0][0][z]

    x, y = 1, 0

    for t in range(24):
        offset = ((t + 1) * (t + 2)) // 2

        for z in range(w):
            rotated_index = (z - offset) % w
            A_prime[x][y][z] = A[x][y][rotated_index]

        x, y = y, (2 * x + 3 * y) % 5

    return A_prime

# %%
def pi(A, w=64):
    """
    Keccak Pi step: rearranges the lanes.

    Args:
        A: 3D state array A[x][y][z], where x, y in [0..4], z in [0..w-1]
        w: lane size

    Returns:
        A_prime: new state array after applying pi step.
    """
    A_prime = [[[0] * w for _ in range(5)] for _ in range(5)]

    for x in range(5):
        for y in range(5):
            for z in range(w):
                A_prime[x][y][z] = A[(x + 3 * y) % 5][x][z]

    return A_prime

# %%
def chi(A, w=64):
    """
    Keccak Chi step: applies non-linear mixing of bits within each row.

    Args:
        A: 3D state array A[x][y][z], where x, y in [0..4], z in [0..w-1]
        w: lane size

    Returns:
        A_prime: new state array after applying chi step.
    """
    A_prime = [[[0] * w for _ in range(5)] for _ in range(5)]

    for x in range(5):
        for y in range(5):
            for z in range(w):
                A_prime[x][y][z] = A[x][y][z] ^ ((A[(x + 1) % 5][y][z] ^ 1) & A[(x + 2) % 5][y][z])

    return A_prime

# %%
def rc_bit(t):
    if t % 255 == 0:
        return 1

    R = ['1', '0', '0', '0', '0', '0', '0', '0']  # '10000000'

    for i in range(1, t % 255 + 1):
        R = ['0'] + R  # Prepend 0 to make it 9 bits

        # XOR operations (bitwise xor with R[8])
        R[0] = str(int(R[0]) ^ int(R[8]))
        R[4] = str(int(R[4]) ^ int(R[8]))
        R[5] = str(int(R[5]) ^ int(R[8]))
        R[6] = str(int(R[6]) ^ int(R[8]))

        R = R[:8]  # Truncate to 8 bits

    return int(R[0])

def iota(A, ir, w=64):
    """
    Keccak Iota step: adds round constant to A[0][0]

    Args:
        A: 3D state array A[x][y][z], where x, y in [0..4], z in [0..w-1]
        ir: round index (0 to 23)
        w: lane size

    Returns:
        A_prime: state array with round constant added to A[0][0]
    """
    A_prime = [[[A[x][y][z] for z in range(w)] for y in range(5)] for x in range(5)]

    RC = [0] * w
    # l = int.bit_length(w) - 1  # log2(w)
    l=6

    for j in range(l + 1):
        bit_position = (1 << j) - 1
        RC[bit_position] = rc_bit(j + 7 * ir)

    for z in range(w):
        A_prime[0][0][z] ^= RC[z]

    return A_prime

# %%
def Rnd(A, ir):
    """
    One round of the Keccak-f permutation.

    Args:
        A: 2D state array A[x][y], where x, y in [0..4], each element is a w-bit integer.
        ir: round index (0 to 23)

    Returns:
        A: State array after applying one round.
    """
    A = theta(A,64)
    A = rho(A)
    A = pi(A)
    A = chi(A)
    A = iota(A, ir)
    return A
def KECCAK_p_1600_24(S):
    A = string_to_state_array(S)
    for ir in range(24):
        A = Rnd(A, ir)
    return state_array_to_string(A)

# %%
def sponge(f, P, r, d):
    n = len(P) // r
    blocks = [P[i*r:(i+1)*r] for i in range(n)]
    c = 1600 - r
    S = '0' * 1600
    for Pi in blocks:
        Pi_padded = Pi + '0'*c
        S = bin(int(S, 2) ^ int(Pi_padded, 2))[2:].zfill(1600)
        S = f(S)
    Z = ''
    while len(Z) < d:
        Z += S[:r]
        if len(Z) >= d:
            break
        S = f(S)
    return Z[:d]

# %%
def bin_to_hex_keccak(bits):
    out = []
    for i in range(0, len(bits), 8):
        b = bits[i:i+8]
        if len(b) < 8:
            b = b.ljust(8, '0')
        out.append(reverse_bits_in_byte(int(b, 2)))
    return ''.join('{:02x}'.format(x) for x in out)
def keccak_hash(msg, r, d, suffix_bits):
    msg_bin = str_to_keccak_bits(msg)
    padded_bits = keccak_pad(msg_bin, r, suffix_bits)
    digest_bits= sponge(KECCAK_p_1600_24, padded_bits, r, d)
    return bin_to_hex_keccak(digest_bits)

# %%
def sha3_256(msg):
    return keccak_hash(msg, 1088, 256, '0110')
def sha3_512(msg):
    return keccak_hash(msg, 576, 512, '0110')
def sha3_384(msg):
    return keccak_hash(msg, 832, 384, '0110')
def sha3_224(msg):
    return keccak_hash(msg, 1152, 224, '0110')
def shake128(msg, outbits):
    return keccak_hash(msg, 1344, outbits, '11111')
def shake256(msg, outbits):
    return keccak_hash(msg, 1088, outbits, '11111')
def keccak_512(msg):
    return keccak_hash(msg, 576, 512, '1')
def keccak_256(msg):
    return keccak_hash(msg, 1088, 256, '1')
def keccak_384(msg):
    return keccak_hash(msg, 832, 384, '1')
def keccak_224(msg):
    return keccak_hash(msg, 1152, 224, '1')

# %%
msg = "hello"
print("SHA3-256:", sha3_256(msg))
print("SHA3-512:", sha3_512(msg))
print("SHA3-384:", sha3_384(msg))
print("SHA3-224:", sha3_224(msg))
print("SHAKE128 (256 bits):", shake128(msg, 256))
print("SHAKE256 (512 bits):", shake256(msg, 512))
print("Keccak-512:", keccak_512(msg))
print("keccak-384: ",keccak_384(msg))
import hashlib
print("hashlib.sha3_256:", hashlib.sha3_256(msg.encode('utf-8')).hexdigest())
print("hashlib.sha3_512:", hashlib.sha3_512(msg.encode('utf-8')).hexdigest())
print("hashlib.sha3_384:", hashlib.sha3_384(msg.encode('utf-8')).hexdigest())
print("hashlib.sha3_224:", hashlib.sha3_224(msg.encode('utf-8')).hexdigest())
print("hashlib.shake_128 (32 bytes):", hashlib.shake_128(msg.encode('utf-8')).hexdigest(32))
print("hashlib.shake_256 (64 bytes):", hashlib.shake_256(msg.encode('utf-8')).hexdigest(64))
print("is match ?", sha3_256(msg) == hashlib.sha3_256(msg.encode('utf-8')).hexdigest())
print("is match?", sha3_512(msg) == hashlib.sha3_512(msg.encode('utf-8')).hexdigest())
print("is match?", sha3_384(msg) == hashlib.sha3_384(msg.encode('utf-8')).hexdigest())
print("is match?", sha3_224(msg) == hashlib.sha3_224(msg.encode('utf-8')).hexdigest())
print("is match?", shake128(msg, 256) == hashlib.shake_128(msg.encode('utf-8')).hexdigest(32))
# Out:
# SHA3-256: 3338be694f50c5f338814986cdf0686453a888b84f424d792af4b9202398f392
# SHA3-512: 75d527c368f2efe848ecf6b073a36767800805e9eef2b1857d5f984f036eb6df891d75f72d9b154518c1cd58835286d1da9a38deba3de98b5a53e5ed78a84976
# SHA3-384: 720aea11019ef06440fbf05d87aa24680a2153df3907b23631e7177ce620fa1330ff07c0fddee54699a4c3ee0ee9d887
# SHA3-224: b87f88c72702fff1748e58b87e9141a42c0dbedc29a78cb0d4a5cd81
# SHAKE128 (256 bits): 8eb4b6a932f280335ee1a279f8c208a349e7bc65daf831d3021c213825292463
# SHAKE256 (512 bits): 1234075ae4a1e77316cf2d8000974581a343b9ebbca7e3d1db83394c30f221626f594e4f0de63902349a5ea5781213215813919f92a4d86d127466e3d07e8be3
# Keccak-512: 52fa80662e64c128f8389c9ea6c73d4c02368004bf4463491900d11aaadca39d47de1b01361f207c512cfa79f0f92c3395c67ff7928e3f5ce3e3c852b392f976
# keccak-384:  dcef6fb7908fd52ba26aaba75121526abbf1217f1c0a31024652d134d3e32fb4cd8e9c703b8f43e7277b59a5cd402175
# hashlib.sha3_256: 3338be694f50c5f338814986cdf0686453a888b84f424d792af4b9202398f392
# hashlib.sha3_512: 75d527c368f2efe848ecf6b073a36767800805e9eef2b1857d5f984f036eb6df891d75f72d9b154518c1cd58835286d1da9a38deba3de98b5a53e5ed78a84976
# hashlib.sha3_384: 720aea11019ef06440fbf05d87aa24680a2153df3907b23631e7177ce620fa1330ff07c0fddee54699a4c3ee0ee9d887
# hashlib.sha3_224: b87f88c72702fff1748e58b87e9141a42c0dbedc29a78cb0d4a5cd81
# hashlib.shake_128 (32 bytes): 8eb4b6a932f280335ee1a279f8c208a349e7bc65daf831d3021c213825292463
# hashlib.shake_256 (64 bytes): 1234075ae4a1e77316cf2d8000974581a343b9ebbca7e3d1db83394c30f221626f594e4f0de63902349a5ea5781213215813919f92a4d86d127466e3d07e8be3
# is match ? True
# is match? True
# is match? True
# is match? True
# is match? True

# %%
import random
import string
import hashlib

def generate_random_word(length):
    """Generates a random word of a given length."""
    letters = string.ascii_lowercase
    return ''.join(random.choice(letters) for i in range(length))

def compare_hashes_for_random_words(num_words=50, word_length=10):
    """
    Generates random words and compares custom SHA3 and SHAKE hashes with hashlib's,
    printing each word and indicating a match with a checkmark.
    """
    print(f"Comparing hashes for {num_words} random words...")

    sha3_256_all_match = True
    sha3_224_all_match = True
    sha3_384_all_match = True
    sha3_512_all_match = True
    shake128_all_match = True
    shake256_all_match = True

    for i in range(num_words):
        # Increase word length with each iteration
        current_word_length = word_length + i
        word = generate_random_word(current_word_length)
        print(f"\nWord '{word}' (Length: {current_word_length}):")

        # SHA3-256 comparison
        custom_hash_256 = sha3_256(word)
        hashlib_hash_256 = hashlib.sha3_256(word.encode('utf-8')).hexdigest()
        print(f"  SHA3-256:")
        print(f"    Custom: {custom_hash_256}")
        print(f"    Hashlib: {hashlib_hash_256}")
        if custom_hash_256 == hashlib_hash_256:
            print("    ✅ Match")
        else:
            print("    Mismatch")
            sha3_256_all_match = False

        # SHA3-224 comparison
        custom_hash_224 = sha3_224(word)
        hashlib_hash_224 = hashlib.sha3_224(word.encode('utf-8')).hexdigest()
        print(f"  SHA3-224:")
        print(f"    Custom: {custom_hash_224}")
        print(f"    Hashlib: {hashlib_hash_224}")
        if custom_hash_224 == hashlib_hash_224:
            print("    ✅ Match")
        else:
            print("    Mismatch")
            sha3_224_all_match = False

        # SHA3-384 comparison
        custom_hash_384 = sha3_384(word)
        hashlib_hash_384 = hashlib.sha3_384(word.encode('utf-8')).hexdigest()
        print(f"  SHA3-384:")
        print(f"    Custom: {custom_hash_384}")
        print(f"    Hashlib: {hashlib_hash_384}")
        if custom_hash_384 == hashlib_hash_384:
            print("    ✅ Match")
        else:
            print("    Mismatch")
            sha3_384_all_match = False

        # SHA3-512 comparison
        custom_hash_512 = sha3_512(word)
        hashlib_hash_512 = hashlib.sha3_512(word.encode('utf-8')).hexdigest()
        print(f"  SHA3-512:")
        print(f"    Custom: {custom_hash_512}")
        print(f"    Hashlib: {hashlib_hash_512}")
        if custom_hash_512 == hashlib_hash_512:
            print("    ✅ Match")
        else:
            print("    Mismatch")
            sha3_512_all_match = False

        # SHAKE128 comparison (32 bytes digest size)
        custom_hash_shake128 = shake128(word, 256) # 256 bits = 32 bytes
        hashlib_hash_shake128 = hashlib.shake_128(word.encode('utf-8')).hexdigest(32)
        print(f"  SHAKE128 (256 bits):")
        print(f"    Custom: {custom_hash_shake128}")
        print(f"    Hashlib: {hashlib_hash_shake128}")
        if custom_hash_shake128 == hashlib_hash_shake128:
            print("    ✅ Match")
        else:
            print("    Mismatch")
            shake128_all_match = False

        # SHAKE256 comparison (32 bytes digest size)
        custom_hash_shake256 = shake256(word, 256) # 256 bits = 32 bytes
        hashlib_hash_shake256 = hashlib.shake_256(word.encode('utf-8')).hexdigest(32)
        print(f"  SHAKE256 (256 bits):")
        print(f"    Custom: {custom_hash_shake256}")
        print(f"    Hashlib: {hashlib_hash_shake256}")
        if custom_hash_shake256 == hashlib_hash_shake256:
            print("    ✅ Match")
        else:
            print("    Mismatch")
            shake256_all_match = False


    print("\n--- Summary ---")
    if sha3_256_all_match:
        print("All generated SHA3-256 hashes matched hashlib's output.")
    else:
        print("Some SHA3-256 hashes did not match hashlib's output.")

    if sha3_224_all_match:
        print("All generated SHA3-224 hashes matched hashlib's output.")
    else:
        print("Some SHA3-224 hashes did not match hashlib's output.")

    if sha3_384_all_match:
        print("All generated SHA3-384 hashes matched hashlib's output.")
    else:
        print("Some SHA3-384 hashes did not match hashlib's output.")

    if sha3_512_all_match:
        print("All generated SHA3-512 hashes matched hashlib's output.")
    else:
        print("Some SHA3-512 hashes did not match hashlib's output.")

    if shake128_all_match:
        print("All generated SHAKE128 (256 bits) hashes matched hashlib's output.")
    else:
        print("Some SHAKE128 (256 bits) hashes did not match hashlib's output.")

    if shake256_all_match:
        print("All generated SHAKE256 (256 bits) hashes matched hashlib's output.")
    else:
        print("Some SHAKE256 (256 bits) hashes did not match hashlib's output.")


# Run the comparison
compare_hashes_for_random_words()
# Out:
# Comparing hashes for 50 random words...
#
# Word 'lcfflabxpv' (Length: 10):
#   SHA3-256:
#     Custom: 26b05ebbca04355a2f964e6869e07a5ca020878e80b86a48e29e470c420672d4
#     Hashlib: 26b05ebbca04355a2f964e6869e07a5ca020878e80b86a48e29e470c420672d4
#     ✅ Match
#   SHA3-224:
#     Custom: b92ea2aa16ae19f2020a44931114bb8bd00dd347b6a91f7c2b2a7b29
#     Hashlib: b92ea2aa16ae19f2020a44931114bb8bd00dd347b6a91f7c2b2a7b29
#     ✅ Match
#   SHA3-384:
#     Custom: d3d4689701dffa526fa9a78ec1b8ca983224b6dc2af377d0895920fce13b572e928a0661879c4d0eb2cecaf4ccb2bf0f
#     Hashlib: d3d4689701dffa526fa9a78ec1b8ca983224b6dc2af377d0895920fce13b572e928a0661879c4d0eb2cecaf4ccb2bf0f
#     ✅ Match
#   SHA3-512:
#     Custom: 81719c4f3d131c24974fc025f3cf3c0b42f13a3be51640eacb6d47b70cbf634b443949909cdddc2c1622d314e3d706992d701e38190a78a8df513f4ac843411c
#     Hashlib: 81719c4f3d131c24974fc025f3cf3c0b42f13a3be51640eacb6d47b70cbf634b443949909cdddc2c1622d314e3d706992d701e38190a78a8df513f4ac843411c
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: c151a80d4d6d489f2392be94db99aa9ec93d841cffc2cda4b2dc694dbf8015f0
#     Hashlib: c151a80d4d6d489f2392be94db99aa9ec93d841cffc2cda4b2dc694dbf8015f0
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: 2943919fd5c497bc4547f2d8e0dac58ccb1803b0579790671a85b04657c698d7
#     Hashlib: 2943919fd5c497bc4547f2d8e0dac58ccb1803b0579790671a85b04657c698d7
#     ✅ Match
#
# Word 'votufzonqni' (Length: 11):
#   SHA3-256:
#     Custom: eb7517646146b57200d00b652d7194726208a7a6902393cc005d5bdfee8a0f98
#     Hashlib: eb7517646146b57200d00b652d7194726208a7a6902393cc005d5bdfee8a0f98
#     ✅ Match
#   SHA3-224:
#     Custom: c1a81d18ebed4223b4649a573df3f42943a7b458d211ec5ed54f5f36
#     Hashlib: c1a81d18ebed4223b4649a573df3f42943a7b458d211ec5ed54f5f36
#     ✅ Match
#   SHA3-384:
#     Custom: 2581639ef29c2dca52b0227cb6d757452280e8b5ae83f590fe3d1b9c9af46c8c01cff4f32f7db452b1c2c73501079e4f
#     Hashlib: 2581639ef29c2dca52b0227cb6d757452280e8b5ae83f590fe3d1b9c9af46c8c01cff4f32f7db452b1c2c73501079e4f
#     ✅ Match
#   SHA3-512:
#     Custom: 475b699879677693d1e4673ab3ebc00c41939e5a1d2ba2187f9c52ec1710c8e7751e7ab71dc0223c0460ac6ad2eb70173abe7a03cdea30b95d5bc1218c2d95f8
#     Hashlib: 475b699879677693d1e4673ab3ebc00c41939e5a1d2ba2187f9c52ec1710c8e7751e7ab71dc0223c0460ac6ad2eb70173abe7a03cdea30b95d5bc1218c2d95f8
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: 230f641060a196783326b8f5a2d85e012711f86371ba9813182dd823f052f634
#     Hashlib: 230f641060a196783326b8f5a2d85e012711f86371ba9813182dd823f052f634
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: ce781261aea2397fe853e4e56e00339a0d2732cd530c1ffe5dcd258fc9a72aa5
#     Hashlib: ce781261aea2397fe853e4e56e00339a0d2732cd530c1ffe5dcd258fc9a72aa5
#     ✅ Match
#
# Word 'oeudjcuwjmec' (Length: 12):
#   SHA3-256:
#     Custom: 579e80f72305958567127357645bbb2346ea30c8cbb4c696f6bce592848bbf2f
#     Hashlib: 579e80f72305958567127357645bbb2346ea30c8cbb4c696f6bce592848bbf2f
#     ✅ Match
#   SHA3-224:
#     Custom: 9f469830dc5a817a274314033cc4e1a4915fdfec1a1fce8ac498f76b
#     Hashlib: 9f469830dc5a817a274314033cc4e1a4915fdfec1a1fce8ac498f76b
#     ✅ Match
#   SHA3-384:
#     Custom: 412ddd23347148045dc9451c1b1ac229b22df99a27f5eca5cdfc733bffc1fcd85afeb55163630a66c07cdc3ca0d2c382
#     Hashlib: 412ddd23347148045dc9451c1b1ac229b22df99a27f5eca5cdfc733bffc1fcd85afeb55163630a66c07cdc3ca0d2c382
#     ✅ Match
#   SHA3-512:
#     Custom: a1ddeeef9f0c7b41e69bd0a3e8ef08698b6f5e5428b7e15ad42adcdad512a69c2aaca70bbbe4315d703b617c5d021bc385da31aaba968df389f16e286d126642
#     Hashlib: a1ddeeef9f0c7b41e69bd0a3e8ef08698b6f5e5428b7e15ad42adcdad512a69c2aaca70bbbe4315d703b617c5d021bc385da31aaba968df389f16e286d126642
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: e945258bfd565ffe7ea33af79e7b3a054a41abe8cde393d33d18471d1ccd4d07
#     Hashlib: e945258bfd565ffe7ea33af79e7b3a054a41abe8cde393d33d18471d1ccd4d07
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: ac74f273a5cac3a8e20512d5d0579fd323ef50c146b52e58e7f84b0031784e23
#     Hashlib: ac74f273a5cac3a8e20512d5d0579fd323ef50c146b52e58e7f84b0031784e23
#     ✅ Match
#
# Word 'vjujsoejzshjg' (Length: 13):
#   SHA3-256:
#     Custom: d0f60c228c52a28d772485aabe6300f007283b4957cfba63a90090a5e05b5a9e
#     Hashlib: d0f60c228c52a28d772485aabe6300f007283b4957cfba63a90090a5e05b5a9e
#     ✅ Match
#   SHA3-224:
#     Custom: 04491d67187e5f6ba19a184c544633be42172510d193ebee8dd30af9
#     Hashlib: 04491d67187e5f6ba19a184c544633be42172510d193ebee8dd30af9
#     ✅ Match
#   SHA3-384:
#     Custom: d169ce543d9eed93a33a433e0d075a0c706c28bd4db176513a790e02111b2dbd28614fd929680749050c22b7ea1054d9
#     Hashlib: d169ce543d9eed93a33a433e0d075a0c706c28bd4db176513a790e02111b2dbd28614fd929680749050c22b7ea1054d9
#     ✅ Match
#   SHA3-512:
#     Custom: 01a51e8fc81fa5127409fdd5a6bb586c82a69143237a87bbced8c63138a3a7d118b9f5866b35a2f201933087e17fbb776f6bb4d8bbdab36c0d4d6f83d3c669e6
#     Hashlib: 01a51e8fc81fa5127409fdd5a6bb586c82a69143237a87bbced8c63138a3a7d118b9f5866b35a2f201933087e17fbb776f6bb4d8bbdab36c0d4d6f83d3c669e6
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: 819b35776d971eb1f55f2c5d170020bb2ad121316932af3f41a9940aff5bd187
#     Hashlib: 819b35776d971eb1f55f2c5d170020bb2ad121316932af3f41a9940aff5bd187
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: 49372945de576b53b29d8369b34510772dae47a830349e412b8d1bccb91d74fd
#     Hashlib: 49372945de576b53b29d8369b34510772dae47a830349e412b8d1bccb91d74fd
#     ✅ Match
#
# Word 'vzmzyxhdzhalmn' (Length: 14):
#   SHA3-256:
#     Custom: 0b32fcda01f30777fee0c722c92c3acdfb85ddb9ec027620ec099df34b55f4d1
#     Hashlib: 0b32fcda01f30777fee0c722c92c3acdfb85ddb9ec027620ec099df34b55f4d1
#     ✅ Match
#   SHA3-224:
#     Custom: 6943f133d55118671c95805ddf99b2d782a8004b11d5071cb3fc7924
#     Hashlib: 6943f133d55118671c95805ddf99b2d782a8004b11d5071cb3fc7924
#     ✅ Match
#   SHA3-384:
#     Custom: 1b6ddd2ab13fab46ac4df04d38befeef507a655b605b79eed8e0d63d7c43a6ebe6fd287fedd25502f4549f836184375e
#     Hashlib: 1b6ddd2ab13fab46ac4df04d38befeef507a655b605b79eed8e0d63d7c43a6ebe6fd287fedd25502f4549f836184375e
#     ✅ Match
#   SHA3-512:
#     Custom: db189e14ae05039bdbbca645a20b39a33bf20af6c9fcdc4e59721450df05297c29c4bf05973fe36286664ca99ca455e84dce7ae451e312b2b919ace912fac0b8
#     Hashlib: db189e14ae05039bdbbca645a20b39a33bf20af6c9fcdc4e59721450df05297c29c4bf05973fe36286664ca99ca455e84dce7ae451e312b2b919ace912fac0b8
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: 0d6595ecd3f6ba752bd634376de9839d1c98cafb396bd7917f86acf29f93ea2f
#     Hashlib: 0d6595ecd3f6ba752bd634376de9839d1c98cafb396bd7917f86acf29f93ea2f
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: bf96376978b2e63b662927509cb2b144cdefe6226db31fec4491e23cf0aa5990
#     Hashlib: bf96376978b2e63b662927509cb2b144cdefe6226db31fec4491e23cf0aa5990
#     ✅ Match
#
# Word 'mijkbkwqsseyurf' (Length: 15):
#   SHA3-256:
#     Custom: e397f81f76af4e47c100bb1c0d22006d5ad0539699119ce19ea064111391d022
#     Hashlib: e397f81f76af4e47c100bb1c0d22006d5ad0539699119ce19ea064111391d022
#     ✅ Match
#   SHA3-224:
#     Custom: e43dd2193fedfac8fcb7af169306ffaacca41cb48e9ae69b80ef8bf4
#     Hashlib: e43dd2193fedfac8fcb7af169306ffaacca41cb48e9ae69b80ef8bf4
#     ✅ Match
#   SHA3-384:
#     Custom: 5ca5b4b42441594c93d63c937fe9ccfdfa54bd419e1615b4cc17fa48b3222844d94886b511932700a677f8245a1a1c3c
#     Hashlib: 5ca5b4b42441594c93d63c937fe9ccfdfa54bd419e1615b4cc17fa48b3222844d94886b511932700a677f8245a1a1c3c
#     ✅ Match
#   SHA3-512:
#     Custom: 24e570a35bd97b87174ce1978ca1ee16ad75f1b29b88549321848fdb3ffc28f262ab510a6dcb96454679bbfad9401ca6be7e5f35e83f0c2a2415465a2c0a96a6
#     Hashlib: 24e570a35bd97b87174ce1978ca1ee16ad75f1b29b88549321848fdb3ffc28f262ab510a6dcb96454679bbfad9401ca6be7e5f35e83f0c2a2415465a2c0a96a6
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: e34b098d3ba80b7d7e7fd1c1fb22018a36c161b5d55b22ec0d3369f39d208f49
#     Hashlib: e34b098d3ba80b7d7e7fd1c1fb22018a36c161b5d55b22ec0d3369f39d208f49
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: c6a50101eecfa74d022c835ab2c5508c3813b2953db9d4ca717dd6e076a9d3f7
#     Hashlib: c6a50101eecfa74d022c835ab2c5508c3813b2953db9d4ca717dd6e076a9d3f7
#     ✅ Match
#
# Word 'mfwxwewbeohvmjwq' (Length: 16):
#   SHA3-256:
#     Custom: e450df0ea154e5ac1242dce4879633f0e178615d1dff1997a47600bec83c4791
#     Hashlib: e450df0ea154e5ac1242dce4879633f0e178615d1dff1997a47600bec83c4791
#     ✅ Match
#   SHA3-224:
#     Custom: d5b57e4a80afc03d67adb8dbabcbc95573ce41f6116b3c2c9ab8a64b
#     Hashlib: d5b57e4a80afc03d67adb8dbabcbc95573ce41f6116b3c2c9ab8a64b
#     ✅ Match
#   SHA3-384:
#     Custom: ea340af3b3c8d04ed9d09e26cb8dc497f138dae30c4ab8829598ecfd8da8f01046227ed42c9ed05ca0063ac90a97d776
#     Hashlib: ea340af3b3c8d04ed9d09e26cb8dc497f138dae30c4ab8829598ecfd8da8f01046227ed42c9ed05ca0063ac90a97d776
#     ✅ Match
#   SHA3-512:
#     Custom: 11fc0f79ea4a90bfddcc7becf72297d160f3e105f4fda42ad0ff50dc69d5cfedb97384d8af89f5cd088cf67157f5a49fa646fceee02423093af8059604570c4d
#     Hashlib: 11fc0f79ea4a90bfddcc7becf72297d160f3e105f4fda42ad0ff50dc69d5cfedb97384d8af89f5cd088cf67157f5a49fa646fceee02423093af8059604570c4d
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: 7fc2ede0aecc1c35e0f44afd52e3515e1a4ec56c8c3b38a2820723a89a81d019
#     Hashlib: 7fc2ede0aecc1c35e0f44afd52e3515e1a4ec56c8c3b38a2820723a89a81d019
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: 4c4a48f863d96bf237c5260b591563ffd9202a98cf41d8c3dcc2c2ff8c8a67bf
#     Hashlib: 4c4a48f863d96bf237c5260b591563ffd9202a98cf41d8c3dcc2c2ff8c8a67bf
#     ✅ Match
#
# Word 'payqgswiexsktsqxu' (Length: 17):
#   SHA3-256:
#     Custom: cff2bf39cd911f4af2aef45f746496ca7fabbc360f3c39ca57f5d2312cb19d6e
#     Hashlib: cff2bf39cd911f4af2aef45f746496ca7fabbc360f3c39ca57f5d2312cb19d6e
#     ✅ Match
#   SHA3-224:
#     Custom: 5a859c7462bae9e20f29235b658c5060dde747782c6d55812133d847
#     Hashlib: 5a859c7462bae9e20f29235b658c5060dde747782c6d55812133d847
#     ✅ Match
#   SHA3-384:
#     Custom: e7564e7a6a53aadeedb7425e4542a7de2b9f5e6c4a33df660fc079188526a95df19253461e6e670c9b485e54b1c70e25
#     Hashlib: e7564e7a6a53aadeedb7425e4542a7de2b9f5e6c4a33df660fc079188526a95df19253461e6e670c9b485e54b1c70e25
#     ✅ Match
#   SHA3-512:
#     Custom: 83b9b22f6a7897abede7b66e82b04719ce2b76ebfaa59301f6cf076dc01432efe583a4979bf63d116b19f3b4942511282b4a99e29f0228461b8c31a8c054edc2
#     Hashlib: 83b9b22f6a7897abede7b66e82b04719ce2b76ebfaa59301f6cf076dc01432efe583a4979bf63d116b19f3b4942511282b4a99e29f0228461b8c31a8c054edc2
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: b6137989bc5bcb6c66e614dcaa7510da7baee5c4f02503db298633fa8db14293
#     Hashlib: b6137989bc5bcb6c66e614dcaa7510da7baee5c4f02503db298633fa8db14293
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: f83e506ad9c8043f55d64b2b58c747323320ea2e21b1e01108864a3abbb6db64
#     Hashlib: f83e506ad9c8043f55d64b2b58c747323320ea2e21b1e01108864a3abbb6db64
#     ✅ Match
#
# Word 'axqmyuwyqyfcbzdnch' (Length: 18):
#   SHA3-256:
#     Custom: 0021afa2cbd4bc1eccc11a155e007b98b1fd5a129ffc4e2c608988d6955d9474
#     Hashlib: 0021afa2cbd4bc1eccc11a155e007b98b1fd5a129ffc4e2c608988d6955d9474
#     ✅ Match
#   SHA3-224:
#     Custom: 3a4bf88dcb70b23f4ad8a4765839a1362241e7d457d9e68cb41f6213
#     Hashlib: 3a4bf88dcb70b23f4ad8a4765839a1362241e7d457d9e68cb41f6213
#     ✅ Match
#   SHA3-384:
#     Custom: e7f9a2f7149addc896c7e75c600cb8e3ff90bf14486b37fbc93009d8ecc19d82bb6b00b4151f2f75b1f8a968d9cc44c6
#     Hashlib: e7f9a2f7149addc896c7e75c600cb8e3ff90bf14486b37fbc93009d8ecc19d82bb6b00b4151f2f75b1f8a968d9cc44c6
#     ✅ Match
#   SHA3-512:
#     Custom: fe6e9cc279ae877d6ca497f0e9363a508f9d1cd28aebd2cfa22538c01cdacce5ac79b9e385c54932dfe804a0f83664eed2a4d8cbbd0ef84ca634eadf088d9a6f
#     Hashlib: fe6e9cc279ae877d6ca497f0e9363a508f9d1cd28aebd2cfa22538c01cdacce5ac79b9e385c54932dfe804a0f83664eed2a4d8cbbd0ef84ca634eadf088d9a6f
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: 71b551d41a6c8fb6a7b691afd8eef71aced58c2dfe604fe27d8251cb38611fef
#     Hashlib: 71b551d41a6c8fb6a7b691afd8eef71aced58c2dfe604fe27d8251cb38611fef
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: e26c26776d5b07397cadb4b75cf2b9d184b2c45f73a97db283e70ab3abd10695
#     Hashlib: e26c26776d5b07397cadb4b75cf2b9d184b2c45f73a97db283e70ab3abd10695
#     ✅ Match
#
# Word 'zlrkftaabrapwfsjygl' (Length: 19):
#   SHA3-256:
#     Custom: 384f0f194a73a6450b0b23546519549dee71ca55777eef3af30275c4efb4d6e4
#     Hashlib: 384f0f194a73a6450b0b23546519549dee71ca55777eef3af30275c4efb4d6e4
#     ✅ Match
#   SHA3-224:
#     Custom: 8f9c6076965638f921c97b387a6193b068fbc7780d741be525840a9b
#     Hashlib: 8f9c6076965638f921c97b387a6193b068fbc7780d741be525840a9b
#     ✅ Match
#   SHA3-384:
#     Custom: 711b4a540f8d363dcb6e9413b308168f58ca734af0160b35afba1974c05a912f7e8b97b46811dd7bdb69f5ef43795661
#     Hashlib: 711b4a540f8d363dcb6e9413b308168f58ca734af0160b35afba1974c05a912f7e8b97b46811dd7bdb69f5ef43795661
#     ✅ Match
#   SHA3-512:
#     Custom: 84fe2f2f2a7570199124d6185bc4cb0616481625ccf6d35da45128ec3bdd1a651fa8aae2ac5c534e5da37bae2c538cbf077e087ae6c140f120a79d66286b0271
#     Hashlib: 84fe2f2f2a7570199124d6185bc4cb0616481625ccf6d35da45128ec3bdd1a651fa8aae2ac5c534e5da37bae2c538cbf077e087ae6c140f120a79d66286b0271
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: ca1e8506298c3c9bfab552f852f387775e59e0a5da1aceb9b3fd821185009a9f
#     Hashlib: ca1e8506298c3c9bfab552f852f387775e59e0a5da1aceb9b3fd821185009a9f
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: 4e9a68c9efbdd84ba72f7d09dd8a3b5f2e36fb9c7928aca54996ced8d5d8eca6
#     Hashlib: 4e9a68c9efbdd84ba72f7d09dd8a3b5f2e36fb9c7928aca54996ced8d5d8eca6
#     ✅ Match
#
# Word 'cnvszkxbasvsjhhealzp' (Length: 20):
#   SHA3-256:
#     Custom: 47c645c4f74ec721ec7d5d1c0dcc865dfef83d5c5340fd10f3044e15890a2fb8
#     Hashlib: 47c645c4f74ec721ec7d5d1c0dcc865dfef83d5c5340fd10f3044e15890a2fb8
#     ✅ Match
#   SHA3-224:
#     Custom: 916a0010a4d657cb077c8418b778010d24a69170f700c86bda2a79e6
#     Hashlib: 916a0010a4d657cb077c8418b778010d24a69170f700c86bda2a79e6
#     ✅ Match
#   SHA3-384:
#     Custom: 674e0b8727ff03cfbf24acc084d058a3546f9726a4ac0c5318b6ade8de31ec68f844c371f005027605e86ae62f1a5f47
#     Hashlib: 674e0b8727ff03cfbf24acc084d058a3546f9726a4ac0c5318b6ade8de31ec68f844c371f005027605e86ae62f1a5f47
#     ✅ Match
#   SHA3-512:
#     Custom: 371922ae32795560c47fcf6adca6eac1008e655c3f3caa51750f4c14a0a34307289c0d49dfd7c61a08daaa2ca1a9a29456c1ce047a404f7e8a9e2c11b260ab74
#     Hashlib: 371922ae32795560c47fcf6adca6eac1008e655c3f3caa51750f4c14a0a34307289c0d49dfd7c61a08daaa2ca1a9a29456c1ce047a404f7e8a9e2c11b260ab74
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: a8ed7f169ae326f04a95e1f963d547c553d4ee3f8f5f808f6599dd2e8960dd7f
#     Hashlib: a8ed7f169ae326f04a95e1f963d547c553d4ee3f8f5f808f6599dd2e8960dd7f
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: a573f498c561791080bb3b96a170af71e4b313612ede5633e136839cbe06ff94
#     Hashlib: a573f498c561791080bb3b96a170af71e4b313612ede5633e136839cbe06ff94
#     ✅ Match
#
# Word 'yyxepgdcjzgymjorbrtst' (Length: 21):
#   SHA3-256:
#     Custom: 24d536186c93f694fee301cfc0aff1927124e68573e39252fc9e9575f53e28e0
#     Hashlib: 24d536186c93f694fee301cfc0aff1927124e68573e39252fc9e9575f53e28e0
#     ✅ Match
#   SHA3-224:
#     Custom: 256979e4c5f04c664a7e9423232e769fbcaa9f3bb61c2985c45f7111
#     Hashlib: 256979e4c5f04c664a7e9423232e769fbcaa9f3bb61c2985c45f7111
#     ✅ Match
#   SHA3-384:
#     Custom: ac145ae7401c1b7475d39154edf033b801d6cd2a65a9b87d5a448f44b358a0516a6f8a6cb26b995c28bd01bd0b1ee803
#     Hashlib: ac145ae7401c1b7475d39154edf033b801d6cd2a65a9b87d5a448f44b358a0516a6f8a6cb26b995c28bd01bd0b1ee803
#     ✅ Match
#   SHA3-512:
#     Custom: ea90d92e0fb54af9e2c495225b83779af868844387240895c739efa19a3e6a79cab55b764d2234cb7af5a181bf9dab65b73cac5111b5f987f455d183e3745067
#     Hashlib: ea90d92e0fb54af9e2c495225b83779af868844387240895c739efa19a3e6a79cab55b764d2234cb7af5a181bf9dab65b73cac5111b5f987f455d183e3745067
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: 1f8e9dd980baa1d2719f9d204b24fdfa01371a145a748fa05bf37b9ae41fab6d
#     Hashlib: 1f8e9dd980baa1d2719f9d204b24fdfa01371a145a748fa05bf37b9ae41fab6d
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: 96608f9c649cea208da0189d7cb2a3cc6d7f4ccfcc39e47e57bbdcc93c2ffeac
#     Hashlib: 96608f9c649cea208da0189d7cb2a3cc6d7f4ccfcc39e47e57bbdcc93c2ffeac
#     ✅ Match
#
# Word 'phgiomykpjvujknhcyrorg' (Length: 22):
#   SHA3-256:
#     Custom: 10659500d792e33c6bd8a2ad8c1d1eba8ee8c10a8d2acc3916c89ecd8de51cc0
#     Hashlib: 10659500d792e33c6bd8a2ad8c1d1eba8ee8c10a8d2acc3916c89ecd8de51cc0
#     ✅ Match
#   SHA3-224:
#     Custom: f58d3a0187c220217ef1311119087174d96a9861c703c963ccbab2b0
#     Hashlib: f58d3a0187c220217ef1311119087174d96a9861c703c963ccbab2b0
#     ✅ Match
#   SHA3-384:
#     Custom: 74ef407f00027821b462db4462a64b0fec7252c7883e7b3b3e44e2b3bec34872dd6ba0b5d1752130bdc1f5c8ceb162a3
#     Hashlib: 74ef407f00027821b462db4462a64b0fec7252c7883e7b3b3e44e2b3bec34872dd6ba0b5d1752130bdc1f5c8ceb162a3
#     ✅ Match
#   SHA3-512:
#     Custom: ac26514a31942b3cca22f7d6698cc7d301baa9cf4593baa6ef8d5fca7b62604ea4b728493ff1c5a3ea31ba92f67fe3e8da23e9986bfe68aca684315467768752
#     Hashlib: ac26514a31942b3cca22f7d6698cc7d301baa9cf4593baa6ef8d5fca7b62604ea4b728493ff1c5a3ea31ba92f67fe3e8da23e9986bfe68aca684315467768752
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: 31439dd952fb5ee16fb348b05641a419936972242f3f5ce653fce7cabe2b0d8b
#     Hashlib: 31439dd952fb5ee16fb348b05641a419936972242f3f5ce653fce7cabe2b0d8b
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: 75f1e179a8c946dfb0fb00117f3a6bc8a62b1d6c8db1c514a1de48b65bce89c5
#     Hashlib: 75f1e179a8c946dfb0fb00117f3a6bc8a62b1d6c8db1c514a1de48b65bce89c5
#     ✅ Match
#
# Word 'hmnglfbmjghfojgsukmvwsm' (Length: 23):
#   SHA3-256:
#     Custom: 4b4c007ed96ed6f0b12e4a5b19ee7289cd3c559cda38bd2aff1ee864a49f6d4c
#     Hashlib: 4b4c007ed96ed6f0b12e4a5b19ee7289cd3c559cda38bd2aff1ee864a49f6d4c
#     ✅ Match
#   SHA3-224:
#     Custom: 45c21b2be52e082475dbede1f416e1ad90b51722ca2d441c5de40e64
#     Hashlib: 45c21b2be52e082475dbede1f416e1ad90b51722ca2d441c5de40e64
#     ✅ Match
#   SHA3-384:
#     Custom: 4346616785d799b71d28035bdd2617cf8a0a9c00785d69d54f3f00626a85c500b466d2d3a9db371dd869debd4c85d6a2
#     Hashlib: 4346616785d799b71d28035bdd2617cf8a0a9c00785d69d54f3f00626a85c500b466d2d3a9db371dd869debd4c85d6a2
#     ✅ Match
#   SHA3-512:
#     Custom: ffd7106365f10f34941626ad6f1b06fbaacc43d2103a2d8440ddf5dba811a7cc5522c06fde47c63bb7cda020e6f0be83af3061ef344bd701a085644cbca37119
#     Hashlib: ffd7106365f10f34941626ad6f1b06fbaacc43d2103a2d8440ddf5dba811a7cc5522c06fde47c63bb7cda020e6f0be83af3061ef344bd701a085644cbca37119
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: 8db62208a70cdc4dbed7cfd60b8fe5b3a346623a3c9558ad26e9db0b4c29e3d0
#     Hashlib: 8db62208a70cdc4dbed7cfd60b8fe5b3a346623a3c9558ad26e9db0b4c29e3d0
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: 23a15ecbc5eeb0ecdf2f838b7877def3189781f7e5761001cae343a4e4ed90b7
#     Hashlib: 23a15ecbc5eeb0ecdf2f838b7877def3189781f7e5761001cae343a4e4ed90b7
#     ✅ Match
#
# Word 'dlftjefgoeujcwrlspyxvadk' (Length: 24):
#   SHA3-256:
#     Custom: 4f118a06ea86c458d9d2a6ba94c2d4407dc88b969b1de820928a9b98db42833e
#     Hashlib: 4f118a06ea86c458d9d2a6ba94c2d4407dc88b969b1de820928a9b98db42833e
#     ✅ Match
#   SHA3-224:
#     Custom: db8fed2737e6d2c468b21740a2601fd9ed97b3cced18ce295c46d85e
#     Hashlib: db8fed2737e6d2c468b21740a2601fd9ed97b3cced18ce295c46d85e
#     ✅ Match
#   SHA3-384:
#     Custom: 1c73b9b23f501b1ad45076ade4a3feefbaba6e35893886ed507bd46815717c095abf8601fdb77dfe9df195d73fbe23d6
#     Hashlib: 1c73b9b23f501b1ad45076ade4a3feefbaba6e35893886ed507bd46815717c095abf8601fdb77dfe9df195d73fbe23d6
#     ✅ Match
#   SHA3-512:
#     Custom: f651353f8a7e48d6e7aa45770d9802744175dc138db1160429540ed21472ad8bb6c2d419c84f221e001ff2257fe9f3d6c961a8c16e7986b9fd21897fd5fd6884
#     Hashlib: f651353f8a7e48d6e7aa45770d9802744175dc138db1160429540ed21472ad8bb6c2d419c84f221e001ff2257fe9f3d6c961a8c16e7986b9fd21897fd5fd6884
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: 6f2a0ac37f4883e90444f584d77f377b5d404c2423e6b6b1a064d5d306aee4bb
#     Hashlib: 6f2a0ac37f4883e90444f584d77f377b5d404c2423e6b6b1a064d5d306aee4bb
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: 2001945b8c1a54997c807d112697152137dfb7a640917f5f02aa5989c3f2d82b
#     Hashlib: 2001945b8c1a54997c807d112697152137dfb7a640917f5f02aa5989c3f2d82b
#     ✅ Match
#
# Word 'qyepzhriotcjsjezhjganouao' (Length: 25):
#   SHA3-256:
#     Custom: e58fe495bd52365c87ac50645dc3aa38bf072099d19bb1b9661f77cc8665e119
#     Hashlib: e58fe495bd52365c87ac50645dc3aa38bf072099d19bb1b9661f77cc8665e119
#     ✅ Match
#   SHA3-224:
#     Custom: 77bc76c3b9183a5d6bb8c0609b1287b14902c19ef535805f36c62158
#     Hashlib: 77bc76c3b9183a5d6bb8c0609b1287b14902c19ef535805f36c62158
#     ✅ Match
#   SHA3-384:
#     Custom: d38ad0c1bb9e3e5cf8e6c0bd2437d25427e841dbb0feb617dc99c40fe4288ef7bc7670b6101702affc30ae8ecf44f5f8
#     Hashlib: d38ad0c1bb9e3e5cf8e6c0bd2437d25427e841dbb0feb617dc99c40fe4288ef7bc7670b6101702affc30ae8ecf44f5f8
#     ✅ Match
#   SHA3-512:
#     Custom: b1b06ae91fc4c970191f1eb4d899d73617ba82d09d015ac32de6f70d287626057d5cf01fcb09c9a619dc12e65742a2022ca7af6ec5874a063bd3358a72df1bae
#     Hashlib: b1b06ae91fc4c970191f1eb4d899d73617ba82d09d015ac32de6f70d287626057d5cf01fcb09c9a619dc12e65742a2022ca7af6ec5874a063bd3358a72df1bae
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: a9c58b184f08fe461c68bb372eed8805c3801756ad93f31b6d89ae1d537d3324
#     Hashlib: a9c58b184f08fe461c68bb372eed8805c3801756ad93f31b6d89ae1d537d3324
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: 9c36823d326efddad40e7dc2d8dbfae7421c03153f1e777818b740023f57c125
#     Hashlib: 9c36823d326efddad40e7dc2d8dbfae7421c03153f1e777818b740023f57c125
#     ✅ Match
#
# Word 'pglysijktdgtkkxlfpmiwelhqq' (Length: 26):
#   SHA3-256:
#     Custom: 304ab378baae9bc382e7a805904ffec66af86addcc2ffc8079c19d85b9a5435a
#     Hashlib: 304ab378baae9bc382e7a805904ffec66af86addcc2ffc8079c19d85b9a5435a
#     ✅ Match
#   SHA3-224:
#     Custom: 5e7e2dc505490bd846a2bd036461a8e31824082aa672b0142ca0192b
#     Hashlib: 5e7e2dc505490bd846a2bd036461a8e31824082aa672b0142ca0192b
#     ✅ Match
#   SHA3-384:
#     Custom: ee508f89e9603aaf240add20ee2b3af7f6939f9024d06bd8f13a79850dee740625eeac597d4502fe7639703c740dc1dd
#     Hashlib: ee508f89e9603aaf240add20ee2b3af7f6939f9024d06bd8f13a79850dee740625eeac597d4502fe7639703c740dc1dd
#     ✅ Match
#   SHA3-512:
#     Custom: b69fd3467d5b2c80544ca77c9f65d63685ba4e63bf41f91065f20a0795ce143f8b4ed0b84392b8496f3c7c9a6dd2216c4d073bdb642f0fddc17b16bbcbf2be1f
#     Hashlib: b69fd3467d5b2c80544ca77c9f65d63685ba4e63bf41f91065f20a0795ce143f8b4ed0b84392b8496f3c7c9a6dd2216c4d073bdb642f0fddc17b16bbcbf2be1f
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: fd6d1bd99c48b5a28a18e5d728759d8e02e81f657b669a9073ea8d188777d876
#     Hashlib: fd6d1bd99c48b5a28a18e5d728759d8e02e81f657b669a9073ea8d188777d876
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: 6b6412f3559d8ccf560bf466d9fdc50210d5b522eb69af16f561a6d3ad99d683
#     Hashlib: 6b6412f3559d8ccf560bf466d9fdc50210d5b522eb69af16f561a6d3ad99d683
#     ✅ Match
#
# Word 'lrxguzcopbxbfjhgydxgalkilva' (Length: 27):
#   SHA3-256:
#     Custom: ba271db6c2ba106aef59099ac3ed24f9922f1d90536fd37f5f53c247f2b04277
#     Hashlib: ba271db6c2ba106aef59099ac3ed24f9922f1d90536fd37f5f53c247f2b04277
#     ✅ Match
#   SHA3-224:
#     Custom: 0d3dccef66ab2343c94c59ae711f479ca9df56edb914163d54e1d9d0
#     Hashlib: 0d3dccef66ab2343c94c59ae711f479ca9df56edb914163d54e1d9d0
#     ✅ Match
#   SHA3-384:
#     Custom: d793a8b9f91e1e84aeec8e07448bcf1b560dc9469b39a4194b7debd66589cd9b4e84993580682c0bf474cbaa84a71dad
#     Hashlib: d793a8b9f91e1e84aeec8e07448bcf1b560dc9469b39a4194b7debd66589cd9b4e84993580682c0bf474cbaa84a71dad
#     ✅ Match
#   SHA3-512:
#     Custom: 3bdc8572f959dfcc738c947246209f95c6174436acacfbe6ef477d2a7a1fe9df821bc0ab166e21fc0b549d41a645ee65c320acf904c38f2e8d60ba81100f3f0e
#     Hashlib: 3bdc8572f959dfcc738c947246209f95c6174436acacfbe6ef477d2a7a1fe9df821bc0ab166e21fc0b549d41a645ee65c320acf904c38f2e8d60ba81100f3f0e
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: 0823096f5dcf0d95141d9d170c5fb4878c5f2092f9a7c507088a3b2ba7f2ffea
#     Hashlib: 0823096f5dcf0d95141d9d170c5fb4878c5f2092f9a7c507088a3b2ba7f2ffea
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: 7370a2d7bd5103d8c1f6703f07c4bef0e1dfa7978bdd73a866ee0141d77a4531
#     Hashlib: 7370a2d7bd5103d8c1f6703f07c4bef0e1dfa7978bdd73a866ee0141d77a4531
#     ✅ Match
#
# Word 'tgwqvjsahiytcbvhashtddxhzezr' (Length: 28):
#   SHA3-256:
#     Custom: 9764c49ef21bc49d5e5d0ec58a8046c300f85669451a973f0427d04c84bf9289
#     Hashlib: 9764c49ef21bc49d5e5d0ec58a8046c300f85669451a973f0427d04c84bf9289
#     ✅ Match
#   SHA3-224:
#     Custom: d07c23965301eb5a64b6ccd539b7c1c2481b04f1fab5aabd801fc2d0
#     Hashlib: d07c23965301eb5a64b6ccd539b7c1c2481b04f1fab5aabd801fc2d0
#     ✅ Match
#   SHA3-384:
#     Custom: 44ac3a48209781ec393a1972b49fffdf017bc9cdc5a7f5bd488074675d8d942c71f5f97e975bf096c6a32eac1e04c435
#     Hashlib: 44ac3a48209781ec393a1972b49fffdf017bc9cdc5a7f5bd488074675d8d942c71f5f97e975bf096c6a32eac1e04c435
#     ✅ Match
#   SHA3-512:
#     Custom: d2c760b7ad564334ec29f1b71f1ea65bad85e70c2fc9fe74853be9cdaa9a2c71585c949fe0569a99ae7b3c0521fd0b7a2ed926dc40077b1b526f9fd0b1e41d53
#     Hashlib: d2c760b7ad564334ec29f1b71f1ea65bad85e70c2fc9fe74853be9cdaa9a2c71585c949fe0569a99ae7b3c0521fd0b7a2ed926dc40077b1b526f9fd0b1e41d53
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: d113cd2dca2c5d9ebe2ab59e11dd5db92c0d515dba8ada0415ea2a7ee4852dd9
#     Hashlib: d113cd2dca2c5d9ebe2ab59e11dd5db92c0d515dba8ada0415ea2a7ee4852dd9
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: 70628be27433563155e4d5560fc69dc29ac93e3af7345057cbf296d0c2194f2d
#     Hashlib: 70628be27433563155e4d5560fc69dc29ac93e3af7345057cbf296d0c2194f2d
#     ✅ Match
#
# Word 'qwppdqteapvrcwxinwiifbmvygrwo' (Length: 29):
#   SHA3-256:
#     Custom: f25b15367b5c85ddb7f8fa364a1b59a6d7128d6ce3f485bf2f4aaf1becf0e3f9
#     Hashlib: f25b15367b5c85ddb7f8fa364a1b59a6d7128d6ce3f485bf2f4aaf1becf0e3f9
#     ✅ Match
#   SHA3-224:
#     Custom: fb15770917603c08704fc9e075bc1ca89e6938f772043b02c84d34dd
#     Hashlib: fb15770917603c08704fc9e075bc1ca89e6938f772043b02c84d34dd
#     ✅ Match
#   SHA3-384:
#     Custom: 4f3d7d65bf9400673e56730d8aaccd519a054e1d325cd9ac60711ca584b675a3d72e39117c0f3b0726e57694d1f80968
#     Hashlib: 4f3d7d65bf9400673e56730d8aaccd519a054e1d325cd9ac60711ca584b675a3d72e39117c0f3b0726e57694d1f80968
#     ✅ Match
#   SHA3-512:
#     Custom: 8618a908a5ea57b02dccd5acd299bb542db9af731fcc8d4e3cba41e4e0b4db51b24d447f35685252d4bc26437ae905fdc7df1b9e5823a7950d67809c2e0c4af9
#     Hashlib: 8618a908a5ea57b02dccd5acd299bb542db9af731fcc8d4e3cba41e4e0b4db51b24d447f35685252d4bc26437ae905fdc7df1b9e5823a7950d67809c2e0c4af9
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: 298da741348b17d5a4361279b65cd850a1792e53148f8e5c83bda4e6538cbaed
#     Hashlib: 298da741348b17d5a4361279b65cd850a1792e53148f8e5c83bda4e6538cbaed
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: 16cce2a22267a1e867e3340a6591f35a5345019f8a3b9f222f810dbc9f237452
#     Hashlib: 16cce2a22267a1e867e3340a6591f35a5345019f8a3b9f222f810dbc9f237452
#     ✅ Match
#
# Word 'cbftjilhrlsdtlsyzqwadltrfilpsy' (Length: 30):
#   SHA3-256:
#     Custom: 1e1c5cfc62728e69b3750121d15e38cae848f676dd9381656cf8779fe412d080
#     Hashlib: 1e1c5cfc62728e69b3750121d15e38cae848f676dd9381656cf8779fe412d080
#     ✅ Match
#   SHA3-224:
#     Custom: dacf70a0f2b29f66b634ea7b8377775ba11f01422c5d78f231d97814
#     Hashlib: dacf70a0f2b29f66b634ea7b8377775ba11f01422c5d78f231d97814
#     ✅ Match
#   SHA3-384:
#     Custom: 555d44acc73712754f0244c3e12698ac12d128470a0c4f8521d1c19f0ea2059777ede5696c8e20d723ce2e7160f7e9a7
#     Hashlib: 555d44acc73712754f0244c3e12698ac12d128470a0c4f8521d1c19f0ea2059777ede5696c8e20d723ce2e7160f7e9a7
#     ✅ Match
#   SHA3-512:
#     Custom: d99d51c625d5aec9156e52cedec59c45197ee5978c33a6bb1cdab866316fba26a2c9326cf364d4bd760538fd21a26d4cc958bb96fad29583625cee1fe9a0b64b
#     Hashlib: d99d51c625d5aec9156e52cedec59c45197ee5978c33a6bb1cdab866316fba26a2c9326cf364d4bd760538fd21a26d4cc958bb96fad29583625cee1fe9a0b64b
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: 976db2503aff0d42f8c354620651ab01e6e06c0de8bc548a3ceff55b9a7dad83
#     Hashlib: 976db2503aff0d42f8c354620651ab01e6e06c0de8bc548a3ceff55b9a7dad83
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: 8eed7ecffa33f26227400706331057b6c1e7f293add1e3e182b50ee0ae2832de
#     Hashlib: 8eed7ecffa33f26227400706331057b6c1e7f293add1e3e182b50ee0ae2832de
#     ✅ Match
#
# Word 'ilkjxnbkeecowoyiqjzmjgdgryhkuvw' (Length: 31):
#   SHA3-256:
#     Custom: 9739831bfac5cb899c5368a17e673e5e0cce4aabf5eae59bb26be09b2083472b
#     Hashlib: 9739831bfac5cb899c5368a17e673e5e0cce4aabf5eae59bb26be09b2083472b
#     ✅ Match
#   SHA3-224:
#     Custom: 1170dab673df00c99519cec30c4961288cae316eeb8341949e1f8b1e
#     Hashlib: 1170dab673df00c99519cec30c4961288cae316eeb8341949e1f8b1e
#     ✅ Match
#   SHA3-384:
#     Custom: 75ba6308a30c44bcb9e37173e2bc65ece5de3362ac54709ebc5eca869fb0823f7218db3acf3c51d2477dcb0fb618d902
#     Hashlib: 75ba6308a30c44bcb9e37173e2bc65ece5de3362ac54709ebc5eca869fb0823f7218db3acf3c51d2477dcb0fb618d902
#     ✅ Match
#   SHA3-512:
#     Custom: 292e23d77661a56cf800c04bcdddc05f8baec5eb88af18ebe7eda66f8b6eb36f87f32406323a81cdd29c04886d4d84b14aa3f652f221d21dc949f970effcfab3
#     Hashlib: 292e23d77661a56cf800c04bcdddc05f8baec5eb88af18ebe7eda66f8b6eb36f87f32406323a81cdd29c04886d4d84b14aa3f652f221d21dc949f970effcfab3
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: 3d6ddfd2495b66e61e8f078a82eda7a6e3d018b7f24914129b7739cda86eb210
#     Hashlib: 3d6ddfd2495b66e61e8f078a82eda7a6e3d018b7f24914129b7739cda86eb210
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: 0cfc85184d230f1ad348f13207bf56af54a29c3e03f5ed72ea74bb1d9c3b3097
#     Hashlib: 0cfc85184d230f1ad348f13207bf56af54a29c3e03f5ed72ea74bb1d9c3b3097
#     ✅ Match
#
# Word 'wkqbcgrwjvuzlnhbicsoluienhbzfbkw' (Length: 32):
#   SHA3-256:
#     Custom: a224cf7a25f3f2257407d38c7fac4979bfc4803466c362aca94c01e96bd337c6
#     Hashlib: a224cf7a25f3f2257407d38c7fac4979bfc4803466c362aca94c01e96bd337c6
#     ✅ Match
#   SHA3-224:
#     Custom: f6e5d946d128c6cd1434a72b4a18cfddcd56ffc1f9c446333fa649cc
#     Hashlib: f6e5d946d128c6cd1434a72b4a18cfddcd56ffc1f9c446333fa649cc
#     ✅ Match
#   SHA3-384:
#     Custom: 07aa29bc1152e8e59de76c2cb347907632b880b8dbe8e1d8cdfc8fdd29754c198be5bde520ae1e0c79ad73ea9da6c711
#     Hashlib: 07aa29bc1152e8e59de76c2cb347907632b880b8dbe8e1d8cdfc8fdd29754c198be5bde520ae1e0c79ad73ea9da6c711
#     ✅ Match
#   SHA3-512:
#     Custom: d4d01cf20841b0165e7973074d8dc86e47c0e52b7da359d6a59cec0d131062ed212094d7d4aa7a3bb74b2192a7c4569cab97a05469cdd78d7734cafa76546618
#     Hashlib: d4d01cf20841b0165e7973074d8dc86e47c0e52b7da359d6a59cec0d131062ed212094d7d4aa7a3bb74b2192a7c4569cab97a05469cdd78d7734cafa76546618
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: ec79b56f5b95bf754d5910335d7da9b014e2a9855f62904a43aa90cbb7e7f62a
#     Hashlib: ec79b56f5b95bf754d5910335d7da9b014e2a9855f62904a43aa90cbb7e7f62a
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: f4629e4b559fddb6bf15f0e6b30fbb95243480bb1dbe8a41bad9c31a07a9f3f7
#     Hashlib: f4629e4b559fddb6bf15f0e6b30fbb95243480bb1dbe8a41bad9c31a07a9f3f7
#     ✅ Match
#
# Word 'tfkuejyyrogflzplxipanikrmurklcdux' (Length: 33):
#   SHA3-256:
#     Custom: a7ca36e56eac0be67875197110efe9e80a9c415322d8f7105a75dc279367c838
#     Hashlib: a7ca36e56eac0be67875197110efe9e80a9c415322d8f7105a75dc279367c838
#     ✅ Match
#   SHA3-224:
#     Custom: 82f181dee69b5d0185b14e22c0698cbd1126c30fb55877e413af3743
#     Hashlib: 82f181dee69b5d0185b14e22c0698cbd1126c30fb55877e413af3743
#     ✅ Match
#   SHA3-384:
#     Custom: ab4c9065080b43d3d11326b281a80524a85d44235af457c72cd4251c3934d32bd2a609dd5638622c739edcd5446a4e0b
#     Hashlib: ab4c9065080b43d3d11326b281a80524a85d44235af457c72cd4251c3934d32bd2a609dd5638622c739edcd5446a4e0b
#     ✅ Match
#   SHA3-512:
#     Custom: c017a13de9e8005e8531911dfdb4816fa5cb277ecd6745275405e3ab487bc1d302fee57697e3153aa5a084b0ac7026f04efd0d0436a5fa5b2c25d0d5f1ee24af
#     Hashlib: c017a13de9e8005e8531911dfdb4816fa5cb277ecd6745275405e3ab487bc1d302fee57697e3153aa5a084b0ac7026f04efd0d0436a5fa5b2c25d0d5f1ee24af
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: 0d904bf6b4725509a5019838982c49db86acad1424bf76468bfcbc3343fc21ad
#     Hashlib: 0d904bf6b4725509a5019838982c49db86acad1424bf76468bfcbc3343fc21ad
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: 2175ba8870dd7c7fc87b2ccb06239b5c9d4901ba73265cfbf5e4894a2b648f78
#     Hashlib: 2175ba8870dd7c7fc87b2ccb06239b5c9d4901ba73265cfbf5e4894a2b648f78
#     ✅ Match
#
# Word 'byakrowsqypeqdrjvurqpktmspnrnlwmej' (Length: 34):
#   SHA3-256:
#     Custom: 006561150f5bf2f0f156932274176fbe6c6cf396a0807cc0d27e5543d4c121d0
#     Hashlib: 006561150f5bf2f0f156932274176fbe6c6cf396a0807cc0d27e5543d4c121d0
#     ✅ Match
#   SHA3-224:
#     Custom: 346816ec54fbf283e6e8721771b6ae7b47cfed1193033f7a0488442d
#     Hashlib: 346816ec54fbf283e6e8721771b6ae7b47cfed1193033f7a0488442d
#     ✅ Match
#   SHA3-384:
#     Custom: f10fbc975af291754576f6729e73bf2f7d6242721b95aba0b9b54e38d1effe8ed236c4bda80d16b10bff9290ad2168d9
#     Hashlib: f10fbc975af291754576f6729e73bf2f7d6242721b95aba0b9b54e38d1effe8ed236c4bda80d16b10bff9290ad2168d9
#     ✅ Match
#   SHA3-512:
#     Custom: ccf098151744c434cf6539cf163c0f08322f099d9016d596712f5a0c77d3e728b21ad946f6a966fe79c6f65b5124092822c7b26773e58bb2399e2ef528af24e8
#     Hashlib: ccf098151744c434cf6539cf163c0f08322f099d9016d596712f5a0c77d3e728b21ad946f6a966fe79c6f65b5124092822c7b26773e58bb2399e2ef528af24e8
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: b4d34b28cd1cc7d1e6a006b328a98c6a35c5453088a4dc0d24896b69360300d3
#     Hashlib: b4d34b28cd1cc7d1e6a006b328a98c6a35c5453088a4dc0d24896b69360300d3
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: 3c8c94416dbc7a349657ec728594a124ffb367ea57be0a4482e0b044e212ac9e
#     Hashlib: 3c8c94416dbc7a349657ec728594a124ffb367ea57be0a4482e0b044e212ac9e
#     ✅ Match
#
# Word 'prsohalairftuelzopnarkwfmwyhtiqrcmz' (Length: 35):
#   SHA3-256:
#     Custom: 96e07629b28da7fc07e8d1ba16bfe9ae76d5aae2b72c7c9b6c744fb3ebbf93dc
#     Hashlib: 96e07629b28da7fc07e8d1ba16bfe9ae76d5aae2b72c7c9b6c744fb3ebbf93dc
#     ✅ Match
#   SHA3-224:
#     Custom: 21466c36631567958d19280666fecbd1b5fa0f1af10b2d29555b1e19
#     Hashlib: 21466c36631567958d19280666fecbd1b5fa0f1af10b2d29555b1e19
#     ✅ Match
#   SHA3-384:
#     Custom: 1f911be895484550e0466ca37e7e751682654f0bbeae9258cefbd490241b91b5a996da74a822a43d5a285866abd383ab
#     Hashlib: 1f911be895484550e0466ca37e7e751682654f0bbeae9258cefbd490241b91b5a996da74a822a43d5a285866abd383ab
#     ✅ Match
#   SHA3-512:
#     Custom: 3ebccb77fb3bd957b91db8eed05577731bcc1354e6d5e3cf54436a50e8899d3ea6e39aad212d0d902e9d7eb120becc7b37e7844438563b88d49335085945e10a
#     Hashlib: 3ebccb77fb3bd957b91db8eed05577731bcc1354e6d5e3cf54436a50e8899d3ea6e39aad212d0d902e9d7eb120becc7b37e7844438563b88d49335085945e10a
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: 03ef6148326f87a5780b10cb39071003f532212b867139fc353a95d8f8d865de
#     Hashlib: 03ef6148326f87a5780b10cb39071003f532212b867139fc353a95d8f8d865de
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: 5db4166deedee568cbd70c7385d5db7fbad0c5d2d4b94a4432acdda6878bfe02
#     Hashlib: 5db4166deedee568cbd70c7385d5db7fbad0c5d2d4b94a4432acdda6878bfe02
#     ✅ Match
#
# Word 'fpiydghwpswvartbprtbqkwsfyexojzjegcw' (Length: 36):
#   SHA3-256:
#     Custom: dc05a795835d29ab10c88d0676798cc5938f8847e332131fbab6caaecb7534e4
#     Hashlib: dc05a795835d29ab10c88d0676798cc5938f8847e332131fbab6caaecb7534e4
#     ✅ Match
#   SHA3-224:
#     Custom: e7bf630404271d92e2f1ab4e89680620c07e13728c154de654548077
#     Hashlib: e7bf630404271d92e2f1ab4e89680620c07e13728c154de654548077
#     ✅ Match
#   SHA3-384:
#     Custom: 838f416b022f41cd2495b3e27f273bb4f86c4206419aa3852579b51c1d86f4b8189d996c48a84b53715bd6401a94a3e4
#     Hashlib: 838f416b022f41cd2495b3e27f273bb4f86c4206419aa3852579b51c1d86f4b8189d996c48a84b53715bd6401a94a3e4
#     ✅ Match
#   SHA3-512:
#     Custom: 2a68c3100e045c521f1497b76a741ec5a258ce8111cd695467eb6b02be1082c20ac571ab6edbb39f10a338c431a043ad3c9b69e16ce2c3969bf6777c406b1fef
#     Hashlib: 2a68c3100e045c521f1497b76a741ec5a258ce8111cd695467eb6b02be1082c20ac571ab6edbb39f10a338c431a043ad3c9b69e16ce2c3969bf6777c406b1fef
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: def78c102e681085ce38ffa366bff223e5b699560d8844bb0d04a7e4e32ca690
#     Hashlib: def78c102e681085ce38ffa366bff223e5b699560d8844bb0d04a7e4e32ca690
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: ce8a8aad94265c9655289e6319a24e094956aaa49bab585ba7931a1f237978a3
#     Hashlib: ce8a8aad94265c9655289e6319a24e094956aaa49bab585ba7931a1f237978a3
#     ✅ Match
#
# Word 'bgxyliavzifvgynxwveevzngshggwpzevphvn' (Length: 37):
#   SHA3-256:
#     Custom: 71231d1b7c5af1780af4120fbef370400d0add5c9d32a55183056873ae37aa74
#     Hashlib: 71231d1b7c5af1780af4120fbef370400d0add5c9d32a55183056873ae37aa74
#     ✅ Match
#   SHA3-224:
#     Custom: 24a00283b89917d6b9b706e2022bffb35d4fdcad867018bb85ccadf0
#     Hashlib: 24a00283b89917d6b9b706e2022bffb35d4fdcad867018bb85ccadf0
#     ✅ Match
#   SHA3-384:
#     Custom: dde9a2dbea69c4b0e39d853109e77481f310e96b08ee14b23d421cb9cc6013d4206093a78f54ebddec160afe409df432
#     Hashlib: dde9a2dbea69c4b0e39d853109e77481f310e96b08ee14b23d421cb9cc6013d4206093a78f54ebddec160afe409df432
#     ✅ Match
#   SHA3-512:
#     Custom: 0a208153d4e0f8a557194773e7bee01471db2d5d221bfeb7e43f02b4801579bdb65b9a05821550dd1fc641ade0265b87ca09b3b5e80234b8df92dd7fd6d84b99
#     Hashlib: 0a208153d4e0f8a557194773e7bee01471db2d5d221bfeb7e43f02b4801579bdb65b9a05821550dd1fc641ade0265b87ca09b3b5e80234b8df92dd7fd6d84b99
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: dedbca43912f453ab7a1ac5b2a386a1f6781e2547a73685cbe4edc27aa9d9347
#     Hashlib: dedbca43912f453ab7a1ac5b2a386a1f6781e2547a73685cbe4edc27aa9d9347
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: 407b9f2c6d85a4ed7dcb1d8bd6630ce383698edc192d05f010dd5c173c5d8b38
#     Hashlib: 407b9f2c6d85a4ed7dcb1d8bd6630ce383698edc192d05f010dd5c173c5d8b38
#     ✅ Match
#
# Word 'borisyujkwsuqkdqbcljxytedfzkiidbvktqmc' (Length: 38):
#   SHA3-256:
#     Custom: baa6bd123a7c3d1b701b6303ba9bd624254c1e6f93a8fb2f6802e7a213f3472f
#     Hashlib: baa6bd123a7c3d1b701b6303ba9bd624254c1e6f93a8fb2f6802e7a213f3472f
#     ✅ Match
#   SHA3-224:
#     Custom: cc71cc88fc88ae723f1dec9a2e64300e17bedcf89111195e853c0224
#     Hashlib: cc71cc88fc88ae723f1dec9a2e64300e17bedcf89111195e853c0224
#     ✅ Match
#   SHA3-384:
#     Custom: 2d6f4ea473fd170247e6e043e69c7d65ae8ff718bbe90ac29c8fb909e93b79272d59c413d4461789c281c3cbb407db1f
#     Hashlib: 2d6f4ea473fd170247e6e043e69c7d65ae8ff718bbe90ac29c8fb909e93b79272d59c413d4461789c281c3cbb407db1f
#     ✅ Match
#   SHA3-512:
#     Custom: 5ef649f57ebd1a36ec54f6606133fa20e654380bf51669e645a02d5b271d752673a220c942feb9afd4a363083c2f2a49be3084402bd0c67e8d97982a7e7c18a3
#     Hashlib: 5ef649f57ebd1a36ec54f6606133fa20e654380bf51669e645a02d5b271d752673a220c942feb9afd4a363083c2f2a49be3084402bd0c67e8d97982a7e7c18a3
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: 344bb9fa6871a3caaa83b8d7db74a7e8b90c5619ef38643953111d9643008a15
#     Hashlib: 344bb9fa6871a3caaa83b8d7db74a7e8b90c5619ef38643953111d9643008a15
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: ed7a614b2b94f8c4b29b3d8d92a96bd581d266d572d120d74cd0e01ac1e9e62a
#     Hashlib: ed7a614b2b94f8c4b29b3d8d92a96bd581d266d572d120d74cd0e01ac1e9e62a
#     ✅ Match
#
# Word 'klkbwjyozyhdbkdtpoovhfsbnixrnmdptydzvpn' (Length: 39):
#   SHA3-256:
#     Custom: d42a502f5b98512dea942370a2504c0837459210e33432ce46beb264f3a9c15f
#     Hashlib: d42a502f5b98512dea942370a2504c0837459210e33432ce46beb264f3a9c15f
#     ✅ Match
#   SHA3-224:
#     Custom: d8fe3912270f378a80054acc63c87025996865d1319425db77fad634
#     Hashlib: d8fe3912270f378a80054acc63c87025996865d1319425db77fad634
#     ✅ Match
#   SHA3-384:
#     Custom: 1b3d66373710780ee58ff97fb47b3b7a76aa04e83d70e58ef963b8322a5e86a0d8e2bbf8289042e9d5671077b6ddbd19
#     Hashlib: 1b3d66373710780ee58ff97fb47b3b7a76aa04e83d70e58ef963b8322a5e86a0d8e2bbf8289042e9d5671077b6ddbd19
#     ✅ Match
#   SHA3-512:
#     Custom: 6346020dbb1edc5be40cd792834fbbe0afa46d2813ee2c111422abe82086008f8cf10298b012894cc6b6f221c2f511397930233d5ca77a5ee249a85148cc27d1
#     Hashlib: 6346020dbb1edc5be40cd792834fbbe0afa46d2813ee2c111422abe82086008f8cf10298b012894cc6b6f221c2f511397930233d5ca77a5ee249a85148cc27d1
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: 18dbded0474bc9c9eb2cb7603de44a8fb91aa451798b734745e961fa656dea40
#     Hashlib: 18dbded0474bc9c9eb2cb7603de44a8fb91aa451798b734745e961fa656dea40
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: b4c1666d6ad78d2fc3f1b050b765635e8d48d5f758bf193c43532109a759c073
#     Hashlib: b4c1666d6ad78d2fc3f1b050b765635e8d48d5f758bf193c43532109a759c073
#     ✅ Match
#
# Word 'gfvsgjdsratbfrsgdgccmoojcuwobikpejzscnqu' (Length: 40):
#   SHA3-256:
#     Custom: f16270fd229433b86a41315e589049c9a7ef40095b3da343c2b31963a199fea6
#     Hashlib: f16270fd229433b86a41315e589049c9a7ef40095b3da343c2b31963a199fea6
#     ✅ Match
#   SHA3-224:
#     Custom: c694b7c30d96be3dec5a6a4b6a2ee76fe37c3654571db0fe47c9aedc
#     Hashlib: c694b7c30d96be3dec5a6a4b6a2ee76fe37c3654571db0fe47c9aedc
#     ✅ Match
#   SHA3-384:
#     Custom: b0bb0dce608f8a9963f9081c7746d35eee07d0d09e4f737298a3f4bfa09650b1bb35112cbb0c200c612f436869e53aa5
#     Hashlib: b0bb0dce608f8a9963f9081c7746d35eee07d0d09e4f737298a3f4bfa09650b1bb35112cbb0c200c612f436869e53aa5
#     ✅ Match
#   SHA3-512:
#     Custom: 138ee18cb590b8a344efefdd295cfba08cac27e6e3391407269f7adbcc5776d329b0884e158bcfc365106e94d10116aeb3b3eca87fb45286cfb5e9191613b247
#     Hashlib: 138ee18cb590b8a344efefdd295cfba08cac27e6e3391407269f7adbcc5776d329b0884e158bcfc365106e94d10116aeb3b3eca87fb45286cfb5e9191613b247
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: 7db53f4066598f6ccec9a8a61c9bd59276559d4a1520c250a6059c2232f4f99e
#     Hashlib: 7db53f4066598f6ccec9a8a61c9bd59276559d4a1520c250a6059c2232f4f99e
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: 8881018ff361dd3bd0c03cd1653a59e0ea69aa70c967352753680edb024bd0fd
#     Hashlib: 8881018ff361dd3bd0c03cd1653a59e0ea69aa70c967352753680edb024bd0fd
#     ✅ Match
#
# Word 'iaiqilphsbfdmejnfrdnhfgilatlvikcihockjhmk' (Length: 41):
#   SHA3-256:
#     Custom: 9d6e42f5ca31457467f3eef6c03efb1437e4a7095773563bed13ab07c4eda0aa
#     Hashlib: 9d6e42f5ca31457467f3eef6c03efb1437e4a7095773563bed13ab07c4eda0aa
#     ✅ Match
#   SHA3-224:
#     Custom: f2695b60cfa93fbf770bcaabaa2d5d7d031c7767b7e23f6f85013744
#     Hashlib: f2695b60cfa93fbf770bcaabaa2d5d7d031c7767b7e23f6f85013744
#     ✅ Match
#   SHA3-384:
#     Custom: 421c56818b249d8a0af69cc86c9c7a0d925da09e02891cbbfff09b52c2294fd6f306626cd6d009834cb2b8fcd0e7ea4b
#     Hashlib: 421c56818b249d8a0af69cc86c9c7a0d925da09e02891cbbfff09b52c2294fd6f306626cd6d009834cb2b8fcd0e7ea4b
#     ✅ Match
#   SHA3-512:
#     Custom: 78676133e9198c8673876cb8fd307007549054397ddde97dc1c15891ee101c4975458cb6de154c04db23abb8844bc0c23b8ff3a8e0b2380911884f5cbef96aa5
#     Hashlib: 78676133e9198c8673876cb8fd307007549054397ddde97dc1c15891ee101c4975458cb6de154c04db23abb8844bc0c23b8ff3a8e0b2380911884f5cbef96aa5
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: 15ada78fd70a39c485e732a7b58d38bffe3fef43349514eaa3b155129af045f8
#     Hashlib: 15ada78fd70a39c485e732a7b58d38bffe3fef43349514eaa3b155129af045f8
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: 2afbb895da8c9e9669299efd95b17d35f17a1b508ee614d34c3ec12c2db2814b
#     Hashlib: 2afbb895da8c9e9669299efd95b17d35f17a1b508ee614d34c3ec12c2db2814b
#     ✅ Match
#
# Word 'gsoflsvesbojheawkizqnstzrdcdgalzkpmgtjitqk' (Length: 42):
#   SHA3-256:
#     Custom: e4c9f6be79cc5db304d4651b3b9a57d180a1382bdafb430cd34d997d32cc037c
#     Hashlib: e4c9f6be79cc5db304d4651b3b9a57d180a1382bdafb430cd34d997d32cc037c
#     ✅ Match
#   SHA3-224:
#     Custom: 617dc3c6d920072fca82750daec6c0fca50483b87c563c802109f5ee
#     Hashlib: 617dc3c6d920072fca82750daec6c0fca50483b87c563c802109f5ee
#     ✅ Match
#   SHA3-384:
#     Custom: db85a6bcf7559237b10b6e7504cce5dfcf0fa66b761457ebdef907fda43957b84d6cc83c54b177a20e91d4a36ada5db3
#     Hashlib: db85a6bcf7559237b10b6e7504cce5dfcf0fa66b761457ebdef907fda43957b84d6cc83c54b177a20e91d4a36ada5db3
#     ✅ Match
#   SHA3-512:
#     Custom: 278d0dd9170a089474185e1ee6f5a59b0853aa07792801d065eaf915933028da300d9192f70d8fcc83374a8d34e2db17b66a38150d9a892f7862dc02d54b7d97
#     Hashlib: 278d0dd9170a089474185e1ee6f5a59b0853aa07792801d065eaf915933028da300d9192f70d8fcc83374a8d34e2db17b66a38150d9a892f7862dc02d54b7d97
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: e19291bc8112f49f00bf0e1c40696b5877b02a29ebd8feea1eaa1273168eeb0e
#     Hashlib: e19291bc8112f49f00bf0e1c40696b5877b02a29ebd8feea1eaa1273168eeb0e
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: 36973ad840dbdc2b2da3888a9e347cfac15fbd294c6d20a6ada5db8c4d542ffe
#     Hashlib: 36973ad840dbdc2b2da3888a9e347cfac15fbd294c6d20a6ada5db8c4d542ffe
#     ✅ Match
#
# Word 'nntflibkqzaveixlazjcolnmdzcdojrxzbpguqidsdf' (Length: 43):
#   SHA3-256:
#     Custom: bc722c13bc02e71f75de63d9e1da4aded34d31fa87eb4d69546ac26b9255239b
#     Hashlib: bc722c13bc02e71f75de63d9e1da4aded34d31fa87eb4d69546ac26b9255239b
#     ✅ Match
#   SHA3-224:
#     Custom: d29a1638a419e29cf5177055b9b2806315683fdfdd0c25f0774020b4
#     Hashlib: d29a1638a419e29cf5177055b9b2806315683fdfdd0c25f0774020b4
#     ✅ Match
#   SHA3-384:
#     Custom: 893d576a87164348c236cec45870089a3f9c2037ef011c687afef1501710612f7b3f27c9bd830e0d4f9fd783f4788cd9
#     Hashlib: 893d576a87164348c236cec45870089a3f9c2037ef011c687afef1501710612f7b3f27c9bd830e0d4f9fd783f4788cd9
#     ✅ Match
#   SHA3-512:
#     Custom: e03e51d5ef2427cf767dcd2eae1c86e33adb3c20bec539e7cfd5aa6491e54dbd49ef9ce7c30076a46203e962680bb1e29fb654495a520b493ea88d6fa21e9f4e
#     Hashlib: e03e51d5ef2427cf767dcd2eae1c86e33adb3c20bec539e7cfd5aa6491e54dbd49ef9ce7c30076a46203e962680bb1e29fb654495a520b493ea88d6fa21e9f4e
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: 5c4a5057031d8324f3295403356c093cceb212a4a23db0d299e1ca9458a55c39
#     Hashlib: 5c4a5057031d8324f3295403356c093cceb212a4a23db0d299e1ca9458a55c39
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: 41858e27d36842bbaf8cefd4750f8838322c8eedaa98c959e9aa7e4343e79ffb
#     Hashlib: 41858e27d36842bbaf8cefd4750f8838322c8eedaa98c959e9aa7e4343e79ffb
#     ✅ Match
#
# Word 'wbvjsxmyshvrrkdpotauxntnwgginmpxgcmjhdiwtvgh' (Length: 44):
#   SHA3-256:
#     Custom: db50b3de4a0bbb8d517765980efcef7a3c9a21524b23ece66a86c09f8a4fc10d
#     Hashlib: db50b3de4a0bbb8d517765980efcef7a3c9a21524b23ece66a86c09f8a4fc10d
#     ✅ Match
#   SHA3-224:
#     Custom: 8dd3e2ceb0efea6fb4940d975d752d4764f2d55435bf129bfc514c37
#     Hashlib: 8dd3e2ceb0efea6fb4940d975d752d4764f2d55435bf129bfc514c37
#     ✅ Match
#   SHA3-384:
#     Custom: 741e87b185693e8894467bcf3a1290a052f6045b2b580ef43c069e03b2b36217e3ab440513a98d79e26fa2827d742ff5
#     Hashlib: 741e87b185693e8894467bcf3a1290a052f6045b2b580ef43c069e03b2b36217e3ab440513a98d79e26fa2827d742ff5
#     ✅ Match
#   SHA3-512:
#     Custom: b85fe16d048932378f64d98ceb22bb78fe0e943da0f07e9a1ee7e73dfead941f1a056b5de1490a12f7469da0f9271f975d46e14cc250df357e0097159a6d9537
#     Hashlib: b85fe16d048932378f64d98ceb22bb78fe0e943da0f07e9a1ee7e73dfead941f1a056b5de1490a12f7469da0f9271f975d46e14cc250df357e0097159a6d9537
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: 88ef85a968454433dcf8acc1fc214c3160d58a0350edc203a8841dc6924b677b
#     Hashlib: 88ef85a968454433dcf8acc1fc214c3160d58a0350edc203a8841dc6924b677b
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: 95d908a57fd761f325397cfcce6286a6d5c4990ae40aadc61ed18b44fb981dbe
#     Hashlib: 95d908a57fd761f325397cfcce6286a6d5c4990ae40aadc61ed18b44fb981dbe
#     ✅ Match
#
# Word 'hkqhjkcogefuzzgvhystqljgdtyoozshbsmczfjdcapjk' (Length: 45):
#   SHA3-256:
#     Custom: 25482292a2f11329989a1d08f6813cd843041228ad1c11a01e9378b3b25d451a
#     Hashlib: 25482292a2f11329989a1d08f6813cd843041228ad1c11a01e9378b3b25d451a
#     ✅ Match
#   SHA3-224:
#     Custom: ad2a4fa416184a6ea88ebb77576d53bd043e7761a11cd997d6c00a4d
#     Hashlib: ad2a4fa416184a6ea88ebb77576d53bd043e7761a11cd997d6c00a4d
#     ✅ Match
#   SHA3-384:
#     Custom: d90418ac3aa0bdb0ac4a0b9d83ea701d98fa85467304b20189c279a54c8f762e2dc9d8b629626e455c0c1f0461f3b700
#     Hashlib: d90418ac3aa0bdb0ac4a0b9d83ea701d98fa85467304b20189c279a54c8f762e2dc9d8b629626e455c0c1f0461f3b700
#     ✅ Match
#   SHA3-512:
#     Custom: f4840e6e445fc2bade28f18420f7a18f0b8b38d9d69a3d00fff71c722466253b4aa4bebf1031d4e5ee331736f80011ade48186738e9130ee403b514eab47aa61
#     Hashlib: f4840e6e445fc2bade28f18420f7a18f0b8b38d9d69a3d00fff71c722466253b4aa4bebf1031d4e5ee331736f80011ade48186738e9130ee403b514eab47aa61
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: 89ccd054b803d691c8cdc0609c853ea30b2d5a4be12988f968ebf6b772da54e7
#     Hashlib: 89ccd054b803d691c8cdc0609c853ea30b2d5a4be12988f968ebf6b772da54e7
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: a26811babb8737ece23d6a2228803647fa8fd2d56527077a7281bda2ed48511b
#     Hashlib: a26811babb8737ece23d6a2228803647fa8fd2d56527077a7281bda2ed48511b
#     ✅ Match
#
# Word 'olqlxkolvedaxezvkahojuqfpmbrpntuevskhlkhdhutxo' (Length: 46):
#   SHA3-256:
#     Custom: 2c5745c79d7f28961af1fcf38385b428dda4651ea310a95285b4c1cfa87573b4
#     Hashlib: 2c5745c79d7f28961af1fcf38385b428dda4651ea310a95285b4c1cfa87573b4
#     ✅ Match
#   SHA3-224:
#     Custom: 7753ca8d00f390f8993c1b8db209169fec40fe1915b2c4b03d453913
# ...
#     ✅ Match
#   SHA3-512:
#     Custom: abf471f6a815b63420723384e0e442dcc3f5ad13b4ec6abda0d2f0845e75438ccab9d8176e84c3325a98c4454033607f7755349b1a42c8794330c38a534f07d4
#     Hashlib: abf471f6a815b63420723384e0e442dcc3f5ad13b4ec6abda0d2f0845e75438ccab9d8176e84c3325a98c4454033607f7755349b1a42c8794330c38a534f07d4
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: f3afc936c74b0ba398486976adfa4ec3fa6863ab090ecbb0274ec417e3f16476
#     Hashlib: f3afc936c74b0ba398486976adfa4ec3fa6863ab090ecbb0274ec417e3f16476
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: 13d78f3930eee21821b261274686fa5d07e05d0ee828cebefd4c04594824a744
#     Hashlib: 13d78f3930eee21821b261274686fa5d07e05d0ee828cebefd4c04594824a744
#     ✅ Match
#
# Word 'mqfnniiyecceuzssvljgbxdhpddzfslqtutlgydzlrbxzdcpc' (Length: 49):
#   SHA3-256:
#     Custom: b6407796a2919bce131382398657245762f87437f16c32d3c7f460ac44acfbf1
#     Hashlib: b6407796a2919bce131382398657245762f87437f16c32d3c7f460ac44acfbf1
#     ✅ Match
#   SHA3-224:
#     Custom: 7e26b5a629480ede60ab8de9465c8b03509c1ed65f8ccb8b1d78b2ce
#     Hashlib: 7e26b5a629480ede60ab8de9465c8b03509c1ed65f8ccb8b1d78b2ce
#     ✅ Match
#   SHA3-384:
#     Custom: 5086cae2add69796463b71eb3dc868c821ec9c89e4ba6ec58d0ab2902134c9009db66d243b433f0e3c22beb9712b9ec0
#     Hashlib: 5086cae2add69796463b71eb3dc868c821ec9c89e4ba6ec58d0ab2902134c9009db66d243b433f0e3c22beb9712b9ec0
#     ✅ Match
#   SHA3-512:
#     Custom: 1dd93178b5f132db86fd3bb5296511b02ca49f5fcb6ef1683791d0755449b79dcb969ff1da3dbfcd8a84ba43e4ea48fdf7d994a3ed0ca708fb7de73aa3060eb4
#     Hashlib: 1dd93178b5f132db86fd3bb5296511b02ca49f5fcb6ef1683791d0755449b79dcb969ff1da3dbfcd8a84ba43e4ea48fdf7d994a3ed0ca708fb7de73aa3060eb4
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: c47cd4e682574638dc9da773f9b871a55d9f2ca44daa59e11171d5e5d46d7ea7
#     Hashlib: c47cd4e682574638dc9da773f9b871a55d9f2ca44daa59e11171d5e5d46d7ea7
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: 0798b2acaef7a192380ce2e6085bcf22d30ebe281129186c18f0739fea981040
#     Hashlib: 0798b2acaef7a192380ce2e6085bcf22d30ebe281129186c18f0739fea981040
#     ✅ Match
#
# Word 'larrtmoxrfkbxmsgjeuqsvmuospwuvaqvdhcffthpnppcgoyql' (Length: 50):
#   SHA3-256:
#     Custom: 5d29f19259a08e1cca32f98f93b983d5aa98d7a6ac550a4ed94156fb2490c142
#     Hashlib: 5d29f19259a08e1cca32f98f93b983d5aa98d7a6ac550a4ed94156fb2490c142
#     ✅ Match
#   SHA3-224:
#     Custom: 50961ab95f82ef4d3b63ee08f850250da6a38c7091c6c86c97751067
#     Hashlib: 50961ab95f82ef4d3b63ee08f850250da6a38c7091c6c86c97751067
#     ✅ Match
#   SHA3-384:
#     Custom: 5ceffab0ac2682e583ab5c3256b8a253d7b3afb043c8f49c604b28cee3ddfbb379d45cd2e1a322f0a6f204f7f3788af7
#     Hashlib: 5ceffab0ac2682e583ab5c3256b8a253d7b3afb043c8f49c604b28cee3ddfbb379d45cd2e1a322f0a6f204f7f3788af7
#     ✅ Match
#   SHA3-512:
#     Custom: 4b42191b1dea2b8250ce2d4e39c7b2db86710c7d9b97aa250218a5577820f64b91e1dca4fed0472b9ad9b28b1a1051df85f334812e52f677abd1c4a256fc883b
#     Hashlib: 4b42191b1dea2b8250ce2d4e39c7b2db86710c7d9b97aa250218a5577820f64b91e1dca4fed0472b9ad9b28b1a1051df85f334812e52f677abd1c4a256fc883b
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: a9d9376608a91b360cbb955f4a269485a847b746c968d2f972003393b8d968ad
#     Hashlib: a9d9376608a91b360cbb955f4a269485a847b746c968d2f972003393b8d968ad
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: 81f30f8c043b8370751e12d20d36d076a20031e87d23c692a827a07520e11eee
#     Hashlib: 81f30f8c043b8370751e12d20d36d076a20031e87d23c692a827a07520e11eee
#     ✅ Match
#
# Word 'qpmolravckadfwgdgcxenrblgdvegesfuqbbezxruoduiobargs' (Length: 51):
#   SHA3-256:
#     Custom: 1e50b4d13d74c40ed18525b282bdf66767a2063e08526a8dbe101a2daf8e18c4
#     Hashlib: 1e50b4d13d74c40ed18525b282bdf66767a2063e08526a8dbe101a2daf8e18c4
#     ✅ Match
#   SHA3-224:
#     Custom: 93953834306184877402f707f399b3a9108ab15cedaf733afbd4965b
#     Hashlib: 93953834306184877402f707f399b3a9108ab15cedaf733afbd4965b
#     ✅ Match
#   SHA3-384:
#     Custom: 2dcce0f7bf591bb736f44d67192fd073e7c20687642e23483df62609d5eced0764044ee0705820fc3dcb37f03494f5ac
#     Hashlib: 2dcce0f7bf591bb736f44d67192fd073e7c20687642e23483df62609d5eced0764044ee0705820fc3dcb37f03494f5ac
#     ✅ Match
#   SHA3-512:
#     Custom: 67bc4b77cb8cd949ec9765fd82c7e6ad8be2a6490e6c55e195dffd51043286cc4b30fdcf22d5b50fb2d57d9d3a789719c8b18637583f85ccb1501bd8e2bb4e52
#     Hashlib: 67bc4b77cb8cd949ec9765fd82c7e6ad8be2a6490e6c55e195dffd51043286cc4b30fdcf22d5b50fb2d57d9d3a789719c8b18637583f85ccb1501bd8e2bb4e52
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: c366f4228049c3eeeb09f8b86d82efb506cbe45f35ea97067744d494c06f6786
#     Hashlib: c366f4228049c3eeeb09f8b86d82efb506cbe45f35ea97067744d494c06f6786
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: 54a41eeef9b2b13c57f101bdeeb0526585a1133ce30ffa384d3c9e96b3b703c4
#     Hashlib: 54a41eeef9b2b13c57f101bdeeb0526585a1133ce30ffa384d3c9e96b3b703c4
#     ✅ Match
#
# Word 'naeehbfdlmwvcyqyplguvcrsjfumwyybinxnctpblxhfdlrefgqi' (Length: 52):
#   SHA3-256:
#     Custom: bbd660e8f25f870204f84197e04736d127fa1e42ad00752e40cf465213bded7a
#     Hashlib: bbd660e8f25f870204f84197e04736d127fa1e42ad00752e40cf465213bded7a
#     ✅ Match
#   SHA3-224:
#     Custom: 03c289f91414a4e1bba257c89bc8300f1f914ded310ef09870e5192f
#     Hashlib: 03c289f91414a4e1bba257c89bc8300f1f914ded310ef09870e5192f
#     ✅ Match
#   SHA3-384:
#     Custom: b77a1ce8900445af0cadb60961117ec5b71b350c79368de6b0d94bc35f75ced75715f28e2ad9de0a66bd546e09697b17
#     Hashlib: b77a1ce8900445af0cadb60961117ec5b71b350c79368de6b0d94bc35f75ced75715f28e2ad9de0a66bd546e09697b17
#     ✅ Match
#   SHA3-512:
#     Custom: e0b955ec2382c513329c51d0b2fedb18b5472945ca1922e92fb24d4d1468db7e0cf2b3444f8e01749aaca4353c97aa7571af667b09d768979e53d75687840b6d
#     Hashlib: e0b955ec2382c513329c51d0b2fedb18b5472945ca1922e92fb24d4d1468db7e0cf2b3444f8e01749aaca4353c97aa7571af667b09d768979e53d75687840b6d
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: 2842c574c69f5876ca0a21258904884ad16b2f2920d7c33cd0f1b841b1b39bd6
#     Hashlib: 2842c574c69f5876ca0a21258904884ad16b2f2920d7c33cd0f1b841b1b39bd6
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: 9e7c5e7af5c97e84e123e8973b8cb644b52141d7d9419459a8ebad2c54cabeaf
#     Hashlib: 9e7c5e7af5c97e84e123e8973b8cb644b52141d7d9419459a8ebad2c54cabeaf
#     ✅ Match
#
# Word 'irlokaiqzldtrvkvicgkngplrjsvfaqfokwkuewvoravdtuwartdm' (Length: 53):
#   SHA3-256:
#     Custom: 38cb0db45c4216e78cbefa831e46dcf49a1adc1813ef758e6c6347c960c4307c
#     Hashlib: 38cb0db45c4216e78cbefa831e46dcf49a1adc1813ef758e6c6347c960c4307c
#     ✅ Match
#   SHA3-224:
#     Custom: a5625f8d6f85def95fd1a638a8f91c1527b6df851e46f6fa549af523
#     Hashlib: a5625f8d6f85def95fd1a638a8f91c1527b6df851e46f6fa549af523
#     ✅ Match
#   SHA3-384:
#     Custom: 5674a8f2392b7375d606d2c81e28e03d035918d8f574bc5306b844b5d98ab3a3c7c758822b4d368817f35d7fdbdfd902
#     Hashlib: 5674a8f2392b7375d606d2c81e28e03d035918d8f574bc5306b844b5d98ab3a3c7c758822b4d368817f35d7fdbdfd902
#     ✅ Match
#   SHA3-512:
#     Custom: 34845ba4bc2ad91d701a635a7bcbbdc71e88c2243f0534d4d15572d253a0b4cdde80fcfcd3ffc977994a52e6f847b1e1ffed098856f80dd03e6a9bee9b44f954
#     Hashlib: 34845ba4bc2ad91d701a635a7bcbbdc71e88c2243f0534d4d15572d253a0b4cdde80fcfcd3ffc977994a52e6f847b1e1ffed098856f80dd03e6a9bee9b44f954
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: 635c6a674c913d74a15f868b01caeaea0d289be7b7e71660dcd78601bde04ead
#     Hashlib: 635c6a674c913d74a15f868b01caeaea0d289be7b7e71660dcd78601bde04ead
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: b73ab8813534b50d467d4977f5b0092e7baace87aa04a47c55fa9b0d303f517e
#     Hashlib: b73ab8813534b50d467d4977f5b0092e7baace87aa04a47c55fa9b0d303f517e
#     ✅ Match
#
# Word 'ddslfefuticawjhuxdahzrftmmgrkpjnyqkkjpheyhxiwqemwkpney' (Length: 54):
#   SHA3-256:
#     Custom: 12caf937022b5afe8354cf3d972999ea8235a2d9943e1ef76f7c8b01f0360f9f
#     Hashlib: 12caf937022b5afe8354cf3d972999ea8235a2d9943e1ef76f7c8b01f0360f9f
#     ✅ Match
#   SHA3-224:
#     Custom: 7db226897aad049f7656c610953963ee474a8111b5ed666b1427ffb3
#     Hashlib: 7db226897aad049f7656c610953963ee474a8111b5ed666b1427ffb3
#     ✅ Match
#   SHA3-384:
#     Custom: 05179b167a102b9a20625ac1b7b06ea72c834dcdb515f9f40f83f2eb71aebd08053c4d17452ab073f67e5319ad5d5887
#     Hashlib: 05179b167a102b9a20625ac1b7b06ea72c834dcdb515f9f40f83f2eb71aebd08053c4d17452ab073f67e5319ad5d5887
#     ✅ Match
#   SHA3-512:
#     Custom: 0c69a4683c21f4365d318316fe90f408e94e6768fa09d8f564aac4f032a67dafbd1bfa0f97226f083fd8fb9de0555f26a3db15c10c714105c48d7d09d8734155
#     Hashlib: 0c69a4683c21f4365d318316fe90f408e94e6768fa09d8f564aac4f032a67dafbd1bfa0f97226f083fd8fb9de0555f26a3db15c10c714105c48d7d09d8734155
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: 425bd9df9f7e1259ca472e58c75763bc9429c5a51447cc1f5f596d2f46fb470a
#     Hashlib: 425bd9df9f7e1259ca472e58c75763bc9429c5a51447cc1f5f596d2f46fb470a
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: 02969d286b87c9ae2f2580a29fc2dbae720e3ce75160d6c5923407762dc86c8e
#     Hashlib: 02969d286b87c9ae2f2580a29fc2dbae720e3ce75160d6c5923407762dc86c8e
#     ✅ Match
#
# Word 'paguaenahxfiwcnvakruywtbfiiscmhpiksrpdsxoeixdcfbvrtwxoq' (Length: 55):
#   SHA3-256:
#     Custom: 4203d31ffe1eb24f8f94213001f7430b209597ccd5dd6ec4a65aed67a95c1b2e
#     Hashlib: 4203d31ffe1eb24f8f94213001f7430b209597ccd5dd6ec4a65aed67a95c1b2e
#     ✅ Match
#   SHA3-224:
#     Custom: 424ceeee727853fafe8218c2ff19b85a391ef73797e4c894123238a5
#     Hashlib: 424ceeee727853fafe8218c2ff19b85a391ef73797e4c894123238a5
#     ✅ Match
#   SHA3-384:
#     Custom: d465f9a6792d48ee08fb31c8ae505dda89d68b27beb77374c32b254e84147752339edc50ab4140403889336cc82dec54
#     Hashlib: d465f9a6792d48ee08fb31c8ae505dda89d68b27beb77374c32b254e84147752339edc50ab4140403889336cc82dec54
#     ✅ Match
#   SHA3-512:
#     Custom: d2a26412349122029a99abaa2b2bb7621f7a04377a56154d8450cfe4955dda0b8c78dd1dca3b62106a5fcaf2e5e7abd3a1d706bcfa7e706647f5642cd841656c
#     Hashlib: d2a26412349122029a99abaa2b2bb7621f7a04377a56154d8450cfe4955dda0b8c78dd1dca3b62106a5fcaf2e5e7abd3a1d706bcfa7e706647f5642cd841656c
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: bbfa3e2e9fd5a131b923f50325a5a7a2821004181869ac302aeecbb566904ea6
#     Hashlib: bbfa3e2e9fd5a131b923f50325a5a7a2821004181869ac302aeecbb566904ea6
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: 1f1a22e321b9d4fcbb4dfb480d3b66626e3c9271416ab454518b0260a4791151
#     Hashlib: 1f1a22e321b9d4fcbb4dfb480d3b66626e3c9271416ab454518b0260a4791151
#     ✅ Match
#
# Word 'alszxclffefdxytnohxnwggewbraebrlorndhobemoglaqrtlstkrnbt' (Length: 56):
#   SHA3-256:
#     Custom: 1f0bd338bd55f0e788bf9ff76c850e170fc058febda25dc8acc23932598274be
#     Hashlib: 1f0bd338bd55f0e788bf9ff76c850e170fc058febda25dc8acc23932598274be
#     ✅ Match
#   SHA3-224:
#     Custom: b013f5d7b175ddcb6a723fbdfa1d34c8474604c7de1589850217376f
#     Hashlib: b013f5d7b175ddcb6a723fbdfa1d34c8474604c7de1589850217376f
#     ✅ Match
#   SHA3-384:
#     Custom: 5f52837c7d767ac9ede1ab14e63ea3fa0270503713b8ed845e59d4813ba59973b890561a03824e679089874742a8c560
#     Hashlib: 5f52837c7d767ac9ede1ab14e63ea3fa0270503713b8ed845e59d4813ba59973b890561a03824e679089874742a8c560
#     ✅ Match
#   SHA3-512:
#     Custom: c76f8406e4e15f1428a1184a48b0c4153e2ba583b98eb103b44623f6081d179a7c3db9fbe72bf090768983f962a1fab2efdf586fbab5650cbbca83f7fc27642a
#     Hashlib: c76f8406e4e15f1428a1184a48b0c4153e2ba583b98eb103b44623f6081d179a7c3db9fbe72bf090768983f962a1fab2efdf586fbab5650cbbca83f7fc27642a
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: 71260f7cc251aec40506ec2223e5e8876ff728c25542cb3033c8fa61801b6e96
#     Hashlib: 71260f7cc251aec40506ec2223e5e8876ff728c25542cb3033c8fa61801b6e96
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: e5896a06d9803e6fa27e1eb15503d2cb41f3b1ea1d9206330ca7aac7782a0cbb
#     Hashlib: e5896a06d9803e6fa27e1eb15503d2cb41f3b1ea1d9206330ca7aac7782a0cbb
#     ✅ Match
#
# Word 'hkymeskpfoevaxqlkwpmucouazdujbuukutyyxkzexehrfurmufahvwda' (Length: 57):
#   SHA3-256:
#     Custom: 317368b99c1d355a51098b6412da601dd7475abc55cfdb8dd52346d686bbd4fa
#     Hashlib: 317368b99c1d355a51098b6412da601dd7475abc55cfdb8dd52346d686bbd4fa
#     ✅ Match
#   SHA3-224:
#     Custom: a1bf6731e2977764e66b8550f931712f3ee0486f2930a24bfc56a403
#     Hashlib: a1bf6731e2977764e66b8550f931712f3ee0486f2930a24bfc56a403
#     ✅ Match
#   SHA3-384:
#     Custom: 0ea6dfa3304bc7f84136096302e636e0cad1f2d54428835f449cb3a40ffe41abcd1bd38f22aa8f5b49750a02000f53c8
#     Hashlib: 0ea6dfa3304bc7f84136096302e636e0cad1f2d54428835f449cb3a40ffe41abcd1bd38f22aa8f5b49750a02000f53c8
#     ✅ Match
#   SHA3-512:
#     Custom: 6046aaa3ccfd858f6d30bf08e4e165178b6dd0e4c4da61910f8d46c83d601db628068816b3490e22dca40a97caecacb9ad45018c05fc79cfe320deb0fb0e1b64
#     Hashlib: 6046aaa3ccfd858f6d30bf08e4e165178b6dd0e4c4da61910f8d46c83d601db628068816b3490e22dca40a97caecacb9ad45018c05fc79cfe320deb0fb0e1b64
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: 3115fa5eeacb2c17f6f97f4f4a13f4020f0e418f20c6a466865fa5ccf62acd86
#     Hashlib: 3115fa5eeacb2c17f6f97f4f4a13f4020f0e418f20c6a466865fa5ccf62acd86
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: 7ce981afc89e7ccbabc4ce6d8f6632c2771a1a19686bf8bbeb3d3d657b7bc446
#     Hashlib: 7ce981afc89e7ccbabc4ce6d8f6632c2771a1a19686bf8bbeb3d3d657b7bc446
#     ✅ Match
#
# Word 'aeofokpsjsosjtvbcjsxsmrqqekjkfyqkhlmdbpiaqwsgigavisgxsowna' (Length: 58):
#   SHA3-256:
#     Custom: 9b255bfa45cca1761594cdfa0074fe0c3b431b3af4655c94ac821525b644b2ed
#     Hashlib: 9b255bfa45cca1761594cdfa0074fe0c3b431b3af4655c94ac821525b644b2ed
#     ✅ Match
#   SHA3-224:
#     Custom: d527442edc7801aaf848d7660c6b2b3919c56b1f65a96a67eebebecc
#     Hashlib: d527442edc7801aaf848d7660c6b2b3919c56b1f65a96a67eebebecc
#     ✅ Match
#   SHA3-384:
#     Custom: 9eb290f180ddd062d5cb462b04f65cc5133c99429bc008f179ae7897b046211343670b552f4edcfc1425ccb43a0d8152
#     Hashlib: 9eb290f180ddd062d5cb462b04f65cc5133c99429bc008f179ae7897b046211343670b552f4edcfc1425ccb43a0d8152
#     ✅ Match
#   SHA3-512:
#     Custom: 142fd588c21d6a399f6c8d52d606b46c1a2b6f11f326faa31ee954afbaa0aa0b79a60c190c33480c29fb06c8af7dda0f20c4738661c32ce4a40baca848a75f79
#     Hashlib: 142fd588c21d6a399f6c8d52d606b46c1a2b6f11f326faa31ee954afbaa0aa0b79a60c190c33480c29fb06c8af7dda0f20c4738661c32ce4a40baca848a75f79
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: bb9acb03488e0aca430e76cdb2d2a005ea984662e8166b9af4eee0bc50b0d635
#     Hashlib: bb9acb03488e0aca430e76cdb2d2a005ea984662e8166b9af4eee0bc50b0d635
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: 5b2294c9911d2f538d20f0895e9c3271492898513c79a7c952d8d3757c372657
#     Hashlib: 5b2294c9911d2f538d20f0895e9c3271492898513c79a7c952d8d3757c372657
#     ✅ Match
#
# Word 'sqoctixoykfqlwnywknqyiuzbdosmjgvbdwliyqwgregrjctahowzenfhmm' (Length: 59):
#   SHA3-256:
#     Custom: 6467746a6f048f4a8fd5febe3a9b484ff9ddbb2cd921cf8efa19c87651f196a8
#     Hashlib: 6467746a6f048f4a8fd5febe3a9b484ff9ddbb2cd921cf8efa19c87651f196a8
#     ✅ Match
#   SHA3-224:
#     Custom: b7c09f85b9846ba6591f4e7b0d8dacc5c28b21c347add5ef3ebe7bb5
#     Hashlib: b7c09f85b9846ba6591f4e7b0d8dacc5c28b21c347add5ef3ebe7bb5
#     ✅ Match
#   SHA3-384:
#     Custom: 6561a9bbc02b9328bd71ebfce4013a5bda903884b4b33866b9b3f29588fa90037d043596b26f211537dbae2da849b69e
#     Hashlib: 6561a9bbc02b9328bd71ebfce4013a5bda903884b4b33866b9b3f29588fa90037d043596b26f211537dbae2da849b69e
#     ✅ Match
#   SHA3-512:
#     Custom: 44598f5f64fadfa6a0ccd77dd8b74fc12c62370d92d3590df60b54b8592c01abcdc1d61b243de8612e0ea2c32b4b5a852d6088a2d5cfc7bc5a4a987777b934b8
#     Hashlib: 44598f5f64fadfa6a0ccd77dd8b74fc12c62370d92d3590df60b54b8592c01abcdc1d61b243de8612e0ea2c32b4b5a852d6088a2d5cfc7bc5a4a987777b934b8
#     ✅ Match
#   SHAKE128 (256 bits):
#     Custom: f2c611c7a35225411ee8897f8b639ac3635e86a03ae863577b528c2219f36cdf
#     Hashlib: f2c611c7a35225411ee8897f8b639ac3635e86a03ae863577b528c2219f36cdf
#     ✅ Match
#   SHAKE256 (256 bits):
#     Custom: bd3ff7397688ff9d4b56249c8c85fcb075350e4c3f55322723dd7aa79c64c282
#     Hashlib: bd3ff7397688ff9d4b56249c8c85fcb075350e4c3f55322723dd7aa79c64c282
#     ✅ Match
#
# --- Summary ---
# All generated SHA3-256 hashes matched hashlib's output.
# All generated SHA3-224 hashes matched hashlib's output.
# All generated SHA3-384 hashes matched hashlib's output.
# All generated SHA3-512 hashes matched hashlib's output.
# All generated SHAKE128 (256 bits) hashes matched hashlib's output.
# All generated SHAKE256 (256 bits) hashes matched hashlib's output.
